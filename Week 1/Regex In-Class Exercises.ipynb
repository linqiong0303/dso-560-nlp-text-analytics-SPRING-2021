# %%
import re
text_file = open("tale-of-two-cities.txt")
text: str = text_file.read()

# %% [markdown]
# ### 1.
# One of the main characters in A Tale of Two Cities is Sydney Carton. How many times is the word `Carton` used?

# %%
len(re.findall(r'\bCarton\b', text))
# Out:
# 154

# %% [markdown]
# ### 2.
# How many times does `the` word the appear in the novel?

# %%
len(re.findall(r'\bthe\b', text))
# Out:
# 7393

# %% [markdown]
# ### 3.

# %% [markdown]
# How would you find replace the stopword `the` using regex from Tale of Two Cities?

# %%
cleaned_text: str = re.sub(r'\bthe\b', '', text)

# %% [markdown]
# ### 4.
#
# What percentage of lines in Dickens' text contain adverbs? For now, you can classify an adverb as a word that ends in `ly`.

# %%
# how many lines in novel
text_file = open("tale-of-two-cities.txt")
lines = text_file.readlines()
num_lines: int = len(lines)
    
# how many lines contain adverbs
matched_lines = 0
for line in lines:
    match = re.search(r'[a-zA-Z]+ly', line)
    if match:
        matched_lines += 1

percentage = matched_lines * 1.0 / num_lines
percentage
# Out:
# 0.1278943278943279

# %%
# how many lines in novel
text_file = open("tale-of-two-cities.txt")
lines = text_file.readlines()
num_lines: int = len(lines)

pattern = r'[a-zA-Z]+ly'

results = list(map(lambda line: re.search(r'[a-zA-Z]+ly', line), lines))
adverb_lines = list(filter(lambda result: result, results))
len(adverb_lines)
# Out:
# 1646

# %%
len(results)
# Out:
# 12870

# %%
adverb_lines
# Out:
# [<_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(48, 56), match='recently'>,
#  <_sre.SRE_Match object; span=(52, 56), match='only'>,
#  <_sre.SRE_Match object; span=(21, 35), match='supernaturally'>,
#  <_sre.SRE_Match object; span=(33, 40), match='earthly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='likely'>,
#  <_sre.SRE_Match object; span=(46, 52), match='likely'>,
#  <_sre.SRE_Match object; span=(30, 41), match='unceasingly'>,
#  <_sre.SRE_Match object; span=(24, 32), match='scarcely'>,
#  <_sre.SRE_Match object; span=(14, 22), match='publicly'>,
#  <_sre.SRE_Match object; span=(32, 41), match='gallantly'>,
#  <_sre.SRE_Match object; span=(41, 49), match='strongly'>,
#  <_sre.SRE_Match object; span=(29, 38), match='violently'>,
#  <_sre.SRE_Match object; span=(17, 26), match='unusually'>,
#  <_sre.SRE_Match object; span=(27, 36), match='intensely'>,
#  <_sre.SRE_Match object; span=(32, 39), match='visibly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='instantly'>,
#  <_sre.SRE_Match object; span=(31, 37), match='nimbly'>,
#  <_sre.SRE_Match object; span=(44, 51), match='audibly'>,
#  <_sre.SRE_Match object; span=(49, 58), match='furiously'>,
#  <_sre.SRE_Match object; span=(15, 23), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 13), match='distrustfully'>,
#  <_sre.SRE_Match object; span=(56, 62), match='mildly'>,
#  <_sre.SRE_Match object; span=(36, 43), match='swiftly'>,
#  <_sre.SRE_Match object; span=(20, 31), match='immediately'>,
#  <_sre.SRE_Match object; span=(42, 50), match='hoarsely'>,
#  <_sre.SRE_Match object; span=(40, 46), match='slowly'>,
#  <_sre.SRE_Match object; span=(9, 15), match='curtly'>,
#  <_sre.SRE_Match object; span=(50, 63), match='expeditiously'>,
#  <_sre.SRE_Match object; span=(42, 54), match='occasionally'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(9, 15), match='softly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(0, 7), match='heavily'>,
#  <_sre.SRE_Match object; span=(13, 19), match='darkly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='vainly'>,
#  <_sre.SRE_Match object; span=(27, 34), match='exactly'>,
#  <_sre.SRE_Match object; span=(50, 56), match='singly'>,
#  <_sre.SRE_Match object; span=(33, 39), match='nearly'>,
#  <_sre.SRE_Match object; span=(61, 65), match='only'>,
#  <_sre.SRE_Match object; span=(21, 29), match='raggedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='jaggedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='strongly'>,
#  <_sre.SRE_Match object; span=(11, 16), match='dimly'>,
#  <_sre.SRE_Match object; span=(47, 53), match='feebly'>,
#  <_sre.SRE_Match object; span=(43, 54), match='principally'>,
#  <_sre.SRE_Match object; span=(29, 40), match='prematurely'>,
#  <_sre.SRE_Match object; span=(21, 26), match='reply'>,
#  <_sre.SRE_Match object; span=(48, 56), match='suddenly'>,
#  <_sre.SRE_Match object; span=(50, 57), match='ghostly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='securely'>,
#  <_sre.SRE_Match object; span=(54, 64), match='distinctly'>,
#  <_sre.SRE_Match object; span=(20, 32), match='successfully'>,
#  <_sre.SRE_Match object; span=(26, 30), match='only'>,
#  <_sre.SRE_Match object; span=(27, 33), match='nicely'>,
#  <_sre.SRE_Match object; span=(50, 57), match='heavily'>,
#  <_sre.SRE_Match object; span=(0, 12), match='Consequently'>,
#  <_sre.SRE_Match object; span=(7, 15), match='formally'>,
#  <_sre.SRE_Match object; span=(7, 14), match='orderly'>,
#  <_sre.SRE_Match object; span=(19, 29), match='habitually'>,
#  <_sre.SRE_Match object; span=(20, 31), match='principally'>,
#  <_sre.SRE_Match object; span=(5, 11), match='easily'>,
#  <_sre.SRE_Match object; span=(62, 66), match='only'>,
#  <_sre.SRE_Match object; span=(16, 22), match='wildly'>,
#  <_sre.SRE_Match object; span=(43, 48), match='madly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='particularly'>,
#  <_sre.SRE_Match object; span=(57, 70), match='unaccountably'>,
#  <_sre.SRE_Match object; span=(4, 10), match='busily'>,
#  <_sre.SRE_Match object; span=(29, 36), match='elderly'>,
#  <_sre.SRE_Match object; span=(19, 28), match='extremely'>,
#  <_sre.SRE_Match object; span=(10, 21), match='immediately'>,
#  <_sre.SRE_Match object; span=(24, 32), match='gloomily'>,
#  <_sre.SRE_Match object; span=(43, 49), match='merely'>,
#  <_sre.SRE_Match object; span=(51, 58), match='heavily'>,
#  <_sre.SRE_Match object; span=(37, 43), match='highly'>,
#  <_sre.SRE_Match object; span=(45, 55), match='gratefully'>,
#  <_sre.SRE_Match object; span=(0, 9), match='naturally'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Naturally'>,
#  <_sre.SRE_Match object; span=(48, 60), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(29, 34), match='truly'>,
#  <_sre.SRE_Match object; span=(12, 20), match='wilfully'>,
#  <_sre.SRE_Match object; span=(63, 70), match='usually'>,
#  <_sre.SRE_Match object; span=(49, 57), match='entirely'>,
#  <_sre.SRE_Match object; span=(0, 9), match='curiously'>,
#  <_sre.SRE_Match object; span=(59, 63), match='only'>,
#  <_sre.SRE_Match object; span=(49, 60), match='confidingly'>,
#  <_sre.SRE_Match object; span=(48, 53), match='truly'>,
#  <_sre.SRE_Match object; span=(36, 41), match='daily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(13, 24), match='collectedly'>,
#  <_sre.SRE_Match object; span=(24, 33), match='intensely'>,
#  <_sre.SRE_Match object; span=(30, 39), match='intensely'>,
#  <_sre.SRE_Match object; span=(64, 70), match='kindly'>,
#  <_sre.SRE_Match object; span=(10, 18), match='directly'>,
#  <_sre.SRE_Match object; span=(12, 18), match='gently'>,
#  <_sre.SRE_Match object; span=(23, 35), match='particularly'>,
#  <_sre.SRE_Match object; span=(45, 52), match='Greatly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='quietly'>,
#  <_sre.SRE_Match object; span=(3, 7), match='Only'>,
#  <_sre.SRE_Match object; span=(57, 67), match='designedly'>,
#  <_sre.SRE_Match object; span=(53, 59), match='openly'>,
#  <_sre.SRE_Match object; span=(2, 11), match='Perfectly'>,
#  <_sre.SRE_Match object; span=(24, 31), match='utterly'>,
#  <_sre.SRE_Match object; span=(24, 30), match='loudly'>,
#  <_sre.SRE_Match object; span=(27, 30), match='fly'>,
#  <_sre.SRE_Match object; span=(6, 12), match='really'>,
#  <_sre.SRE_Match object; span=(12, 26), match='simultaneously'>,
#  <_sre.SRE_Match object; span=(0, 6), match='softly'>,
#  <_sre.SRE_Match object; span=(32, 43), match='indignantly'>,
#  <_sre.SRE_Match object; span=(19, 30), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(5, 11), match='likely'>,
#  <_sre.SRE_Match object; span=(24, 33), match='expressly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(60, 70), match='especially'>,
#  <_sre.SRE_Match object; span=(32, 40), match='suddenly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='saintly'>,
#  <_sre.SRE_Match object; span=(10, 20), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(36, 40), match='only'>,
#  <_sre.SRE_Match object; span=(53, 59), match='rudely'>,
#  <_sre.SRE_Match object; span=(29, 40), match='gloweringly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='abruptly'>,
#  <_sre.SRE_Match object; span=(45, 49), match='only'>,
#  <_sre.SRE_Match object; span=(5, 11), match='sickly'>,
#  <_sre.SRE_Match object; span=(54, 64), match='completely'>,
#  <_sre.SRE_Match object; span=(0, 12), match='accidentally'>,
#  <_sre.SRE_Match object; span=(52, 61), match='extremely'>,
#  <_sre.SRE_Match object; span=(7, 16), match='wolfishly'>,
#  <_sre.SRE_Match object; span=(29, 41), match='deliberately'>,
#  <_sre.SRE_Match object; span=(13, 20), match='crisply'>,
#  <_sre.SRE_Match object; span=(0, 9), match='evidently'>,
#  <_sre.SRE_Match object; span=(0, 7), match='heavily'>,
#  <_sre.SRE_Match object; span=(45, 51), match='darkly'>,
#  <_sre.SRE_Match object; span=(23, 34), match='accordingly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='elderly'>,
#  <_sre.SRE_Match object; span=(64, 70), match='supply'>,
#  <_sre.SRE_Match object; span=(0, 7), match='elderly'>,
#  <_sre.SRE_Match object; span=(4, 12), match='slightly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='observantly'>,
#  <_sre.SRE_Match object; span=(56, 63), match='elderly'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='deeply'>,
#  <_sre.SRE_Match object; span=(0, 6), match='gently'>,
#  <_sre.SRE_Match object; span=(62, 68), match='slowly'>,
#  <_sre.SRE_Match object; span=(9, 16), match='greatly'>,
#  <_sre.SRE_Match object; span=(19, 25), match='sickly'>,
#  <_sre.SRE_Match object; span=(32, 41), match='carefully'>,
#  <_sre.SRE_Match object; span=(26, 31), match='reply'>,
#  <_sre.SRE_Match object; span=(34, 41), match='heavily'>,
#  <_sre.SRE_Match object; span=(38, 46), match='bitterly'>,
#  <_sre.SRE_Match object; span=(34, 38), match='only'>,
#  <_sre.SRE_Match object; span=(15, 21), match='slowly'>,
#  <_sre.SRE_Match object; span=(45, 53), match='intently'>,
#  <_sre.SRE_Match object; span=(32, 40), match='silently'>,
#  <_sre.SRE_Match object; span=(18, 24), match='likely'>,
#  <_sre.SRE_Match object; span=(38, 47), match='evidently'>,
#  <_sre.SRE_Match object; span=(49, 57), match='clumsily'>,
#  <_sre.SRE_Match object; span=(23, 30), match='heavily'>,
#  <_sre.SRE_Match object; span=(11, 17), match='slowly'>,
#  <_sre.SRE_Match object; span=(18, 26), match='securely'>,
#  <_sre.SRE_Match object; span=(5, 17), match='methodically'>,
#  <_sre.SRE_Match object; span=(24, 31), match='Finally'>,
#  <_sre.SRE_Match object; span=(42, 48), match='slowly'>,
#  <_sre.SRE_Match object; span=(50, 58), match='entirely'>,
#  <_sre.SRE_Match object; span=(26, 32), match='lonely'>,
#  <_sre.SRE_Match object; span=(59, 63), match='only'>,
#  <_sre.SRE_Match object; span=(49, 58), match='similarly'>,
#  <_sre.SRE_Match object; span=(52, 60), match='raggedly'>,
#  <_sre.SRE_Match object; span=(38, 49), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='really'>,
#  <_sre.SRE_Match object; span=(7, 18), match='unnaturally'>,
#  <_sre.SRE_Match object; span=(50, 61), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(17, 25), match='silently'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Assuredly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(43, 49), match='slowly'>,
#  <_sre.SRE_Match object; span=(30, 41), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='fixedly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='fixedly'>,
#  <_sre.SRE_Match object; span=(56, 64), match='actively'>,
#  <_sre.SRE_Match object; span=(51, 60), match='gradually'>,
#  <_sre.SRE_Match object; span=(19, 26), match='exactly'>,
#  <_sre.SRE_Match object; span=(24, 28), match='only'>,
#  <_sre.SRE_Match object; span=(0, 7), match='exactly'>,
#  <_sre.SRE_Match object; span=(14, 25), match='attentively'>,
#  <_sre.SRE_Match object; span=(48, 55), match='Finally'>,
#  <_sre.SRE_Match object; span=(0, 14), match='unquestionably'>,
#  <_sre.SRE_Match object; span=(39, 46), match='visibly'>,
#  <_sre.SRE_Match object; span=(30, 36), match='softly'>,
#  <_sre.SRE_Match object; span=(58, 67), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(24, 34), match='doubtfully'>,
#  <_sre.SRE_Match object; span=(20, 26), match='really'>,
#  <_sre.SRE_Match object; span=(43, 52), match='carefully'>,
#  <_sre.SRE_Match object; span=(51, 58), match='closely'>,
#  <_sre.SRE_Match object; span=(0, 10), match='coherently'>,
#  <_sre.SRE_Match object; span=(36, 45), match='perfectly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(9, 17), match='gloomily'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(63, 67), match='only'>,
#  <_sre.SRE_Match object; span=(6, 13), match='hastily'>,
#  <_sre.SRE_Match object; span=(10, 22), match='occasionally'>,
#  <_sre.SRE_Match object; span=(29, 39), match='invariably'>,
#  <_sre.SRE_Match object; span=(58, 65), match='readily'>,
#  <_sre.SRE_Match object; span=(3, 12), match='evidently'>,
#  <_sre.SRE_Match object; span=(52, 65), match='instinctively'>,
#  <_sre.SRE_Match object; span=(47, 51), match='Only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='miserably'>,
#  <_sre.SRE_Match object; span=(8, 19), match='immediately'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quickly'>,
#  <_sre.SRE_Match object; span=(38, 45), match='gravely'>,
#  <_sre.SRE_Match object; span=(11, 15), match='ugly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='highly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='hardly'>,
#  <_sre.SRE_Match object; span=(61, 67), match='family'>,
#  <_sre.SRE_Match object; span=(59, 64), match='newly'>,
#  <_sre.SRE_Match object; span=(15, 26), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(4, 11), match='exactly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='privately'>,
#  <_sre.SRE_Match object; span=(38, 45), match='gravely'>,
#  <_sre.SRE_Match object; span=(55, 59), match='only'>,
#  <_sre.SRE_Match object; span=(22, 35), match='spectacularly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='grisly'>,
#  <_sre.SRE_Match object; span=(32, 39), match='stately'>,
#  <_sre.SRE_Match object; span=(39, 47), match='easterly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='apparently'>,
#  <_sre.SRE_Match object; span=(50, 58), match='decently'>,
#  <_sre.SRE_Match object; span=(28, 35), match='heavily'>,
#  <_sre.SRE_Match object; span=(13, 20), match='orderly'>,
#  <_sre.SRE_Match object; span=(9, 13), match='only'>,
#  <_sre.SRE_Match object; span=(33, 37), match='only'>,
#  <_sre.SRE_Match object; span=(23, 31), match='strongly'>,
#  <_sre.SRE_Match object; span=(8, 12), match='only'>,
#  <_sre.SRE_Match object; span=(36, 47), match='religiously'>,
#  <_sre.SRE_Match object; span=(11, 18), match='greatly'>,
#  <_sre.SRE_Match object; span=(34, 40), match='merely'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Exceedingly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='scarcely'>,
#  <_sre.SRE_Match object; span=(20, 26), match='bodily'>,
#  <_sre.SRE_Match object; span=(16, 25), match='extremely'>,
#  <_sre.SRE_Match object; span=(0, 10), match='restlessly'>,
#  <_sre.SRE_Match object; span=(29, 34), match='early'>,
#  <_sre.SRE_Match object; span=(23, 35), match='deliberately'>,
#  <_sre.SRE_Match object; span=(41, 50), match='certainly'>,
#  <_sre.SRE_Match object; span=(20, 26), match='deadly'>,
#  <_sre.SRE_Match object; span=(4, 15), match='continually'>,
#  <_sre.SRE_Match object; span=(38, 52), match='systematically'>,
#  <_sre.SRE_Match object; span=(8, 15), match='quietly'>,
#  <_sre.SRE_Match object; span=(7, 11), match='only'>,
#  <_sre.SRE_Match object; span=(39, 49), match='grudgingly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='nearly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='quietly'>,
#  <_sre.SRE_Match object; span=(50, 59), match='Presently'>,
#  <_sre.SRE_Match object; span=(0, 7), match='plainly'>,
#  <_sre.SRE_Match object; span=(53, 63), match='shamefully'>,
#  <_sre.SRE_Match object; span=(0, 8), match='wickedly'>,
#  <_sre.SRE_Match object; span=(29, 41), match='circuitously'>,
#  <_sre.SRE_Match object; span=(51, 59), match='mentally'>,
#  <_sre.SRE_Match object; span=(0, 10), match='composedly'>,
#  <_sre.SRE_Match object; span=(18, 25), match='ghastly'>,
#  <_sre.SRE_Match object; span=(5, 16), match='immediately'>,
#  <_sre.SRE_Match object; span=(37, 46), match='evidently'>,
#  <_sre.SRE_Match object; span=(18, 28), match='strikingly'>,
#  <_sre.SRE_Match object; span=(33, 43), match='powerfully'>,
#  <_sre.SRE_Match object; span=(41, 47), match='slowly'>,
#  <_sre.SRE_Match object; span=(42, 50), match='steadily'>,
#  <_sre.SRE_Match object; span=(61, 68), match='happily'>,
#  <_sre.SRE_Match object; span=(14, 23), match='assuredly'>,
#  <_sre.SRE_Match object; span=(12, 20), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 10), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 10), match='unworthily'>,
#  <_sre.SRE_Match object; span=(37, 41), match='holy'>,
#  <_sre.SRE_Match object; span=(43, 53), match='habitually'>,
#  <_sre.SRE_Match object; span=(17, 27), match='positively'>,
#  <_sre.SRE_Match object; span=(9, 16), match='exactly'>,
#  <_sre.SRE_Match object; span=(41, 48), match='exactly'>,
#  <_sre.SRE_Match object; span=(45, 53), match='modestly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='precisely'>,
#  <_sre.SRE_Match object; span=(53, 62), match='Certainly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='Frequently'>,
#  <_sre.SRE_Match object; span=(53, 63), match='Positively'>,
#  <_sre.SRE_Match object; span=(30, 33), match='Cly'>,
#  <_sre.SRE_Match object; span=(50, 54), match='only'>,
#  <_sre.SRE_Match object; span=(61, 67), match='merely'>,
#  <_sre.SRE_Match object; span=(35, 47), match='particularly'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(21, 29), match='unlikely'>,
#  <_sre.SRE_Match object; span=(5, 14), match='certainly'>,
#  <_sre.SRE_Match object; span=(40, 44), match='only'>,
#  <_sre.SRE_Match object; span=(14, 22), match='untimely'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(55, 59), match='only'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Hardly'>,
#  <_sre.SRE_Match object; span=(11, 20), match='unhappily'>,
#  <_sre.SRE_Match object; span=(41, 49), match='fiercely'>,
#  <_sre.SRE_Match object; span=(44, 51), match='faintly'>,
#  <_sre.SRE_Match object; span=(17, 25), match='lovingly'>,
#  <_sre.SRE_Match object; span=(3, 11), match='Possibly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(42, 51), match='perfectly'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(5, 15), match='laughingly'>,
#  <_sre.SRE_Match object; span=(6, 14), match='strongly'>,
#  <_sre.SRE_Match object; span=(8, 21), match='unconsciously'>,
#  <_sre.SRE_Match object; span=(0, 9), match='painfully'>,
#  <_sre.SRE_Match object; span=(46, 57), match='accordingly'>,
#  <_sre.SRE_Match object; span=(12, 17), match='newly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='slovenly'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='family'>,
#  <_sre.SRE_Match object; span=(13, 19), match='likely'>,
#  <_sre.SRE_Match object; span=(11, 14), match='Cly'>,
#  <_sre.SRE_Match object; span=(46, 52), match='Lastly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='decidedly'>,
#  <_sre.SRE_Match object; span=(8, 17), match='anxiously'>,
#  <_sre.SRE_Match object; span=(19, 25), match='slowly'>,
#  <_sre.SRE_Match object; span=(56, 66), match='especially'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(44, 55), match='undoubtedly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='hardly'>,
#  <_sre.SRE_Match object; span=(60, 67), match='audibly'>,
#  <_sre.SRE_Match object; span=(33, 42), match='evidently'>,
#  <_sre.SRE_Match object; span=(16, 22), match='easily'>,
#  <_sre.SRE_Match object; span=(10, 17), match='greatly'>,
#  <_sre.SRE_Match object; span=(47, 55), match='publicly'>,
#  <_sre.SRE_Match object; span=(28, 36), match='directly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='naturally'>,
#  <_sre.SRE_Match object; span=(8, 14), match='deeply'>,
#  <_sre.SRE_Match object; span=(29, 33), match='only'>,
#  <_sre.SRE_Match object; span=(28, 35), match='heavily'>,
#  <_sre.SRE_Match object; span=(31, 44), match='uncomfortably'>,
#  <_sre.SRE_Match object; span=(2, 9), match='Hastily'>,
#  <_sre.SRE_Match object; span=(34, 40), match='nearly'>,
#  <_sre.SRE_Match object; span=(11, 16), match='dimly'>,
#  <_sre.SRE_Match object; span=(57, 65), match='fitfully'>,
#  <_sre.SRE_Match object; span=(2, 6), match='Only'>,
#  <_sre.SRE_Match object; span=(49, 59), match='absolutely'>,
#  <_sre.SRE_Match object; span=(33, 42), match='fervently'>,
#  <_sre.SRE_Match object; span=(31, 37), match='warmly'>,
#  <_sre.SRE_Match object; span=(36, 43), match='morally'>,
#  <_sre.SRE_Match object; span=(52, 59), match='grossly'>,
#  <_sre.SRE_Match object; span=(27, 33), match='likely'>,
#  <_sre.SRE_Match object; span=(5, 12), match='clearly'>,
#  <_sre.SRE_Match object; span=(33, 48), match='disinterestedly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='previously'>,
#  <_sre.SRE_Match object; span=(32, 41), match='pointedly'>,
#  <_sre.SRE_Match object; span=(27, 33), match='softly'>,
#  <_sre.SRE_Match object; span=(5, 11), match='slowly'>,
#  <_sre.SRE_Match object; span=(37, 43), match='nearly'>,
#  <_sre.SRE_Match object; span=(59, 67), match='silently'>,
#  <_sre.SRE_Match object; span=(32, 38), match='warmly'>,
#  <_sre.SRE_Match object; span=(41, 51), match='carelessly'>,
#  <_sre.SRE_Match object; span=(60, 66), match='really'>,
#  <_sre.SRE_Match object; span=(42, 48), match='really'>,
#  <_sre.SRE_Match object; span=(32, 42), match='thoroughly'>,
#  <_sre.SRE_Match object; span=(5, 11), match='hardly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='faintly'>,
#  <_sre.SRE_Match object; span=(20, 25), match='fully'>,
#  <_sre.SRE_Match object; span=(8, 19), match='frightfully'>,
#  <_sre.SRE_Match object; span=(13, 21), match='bitterly'>,
#  <_sre.SRE_Match object; span=(29, 36), match='finally'>,
#  <_sre.SRE_Match object; span=(36, 45), match='presently'>,
#  <_sre.SRE_Match object; span=(11, 19), match='mightily'>,
#  <_sre.SRE_Match object; span=(27, 33), match='timely'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(18, 30), match='particularly'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(57, 65), match='minutely'>,
#  <_sre.SRE_Match object; span=(10, 22), match='particularly'>,
#  <_sre.SRE_Match object; span=(16, 28), match='particularly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(18, 28), match='cautiously'>,
#  <_sre.SRE_Match object; span=(24, 33), match='specially'>,
#  <_sre.SRE_Match object; span=(3, 8), match='daily'>,
#  <_sre.SRE_Match object; span=(6, 10), match='ally'>,
#  <_sre.SRE_Match object; span=(0, 10), match='stealthily'>,
#  <_sre.SRE_Match object; span=(0, 9), match='amazingly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='dexterously'>,
#  <_sre.SRE_Match object; span=(2, 10), match='Sullenly'>,
#  <_sre.SRE_Match object; span=(58, 67), match='partially'>,
#  <_sre.SRE_Match object; span=(9, 14), match='gaily'>,
#  <_sre.SRE_Match object; span=(3, 7), match='Only'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(42, 47), match='fully'>,
#  <_sre.SRE_Match object; span=(60, 65), match='bully'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Partly'>,
#  <_sre.SRE_Match object; span=(2, 12), match='Apparently'>,
#  <_sre.SRE_Match object; span=(10, 16), match='slowly'>,
#  <_sre.SRE_Match object; span=(39, 45), match='coldly'>,
#  <_sre.SRE_Match object; span=(2, 7), match='Sadly'>,
#  <_sre.SRE_Match object; span=(62, 67), match='early'>,
#  <_sre.SRE_Match object; span=(43, 50), match='Firstly'>,
#  <_sre.SRE_Match object; span=(7, 15), match='secondly'>,
#  <_sre.SRE_Match object; span=(23, 29), match='family'>,
#  <_sre.SRE_Match object; span=(12, 21), match='generally'>,
#  <_sre.SRE_Match object; span=(61, 67), match='likely'>,
#  <_sre.SRE_Match object; span=(42, 53), match='brilliantly'>,
#  <_sre.SRE_Match object; span=(2, 8), match='lonely'>,
#  <_sre.SRE_Match object; span=(0, 12), match='Occasionally'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(2, 10), match='Possibly'>,
#  <_sre.SRE_Match object; span=(32, 40), match='innately'>,
#  <_sre.SRE_Match object; span=(52, 58), match='freely'>,
#  <_sre.SRE_Match object; span=(21, 30), match='smilingly'>,
#  <_sre.SRE_Match object; span=(36, 46), match='changingly'>,
#  <_sre.SRE_Match object; span=(44, 51), match='sharply'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(30, 39), match='certainly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='really'>,
#  <_sre.SRE_Match object; span=(36, 42), match='really'>,
#  <_sre.SRE_Match object; span=(33, 37), match='only'>,
#  <_sre.SRE_Match object; span=(30, 42), match='immeasurably'>,
#  <_sre.SRE_Match object; span=(18, 26), match='friendly'>,
#  <_sre.SRE_Match object; span=(29, 35), match='kindly'>,
#  <_sre.SRE_Match object; span=(8, 14), match='Surely'>,
#  <_sre.SRE_Match object; span=(21, 35), match='unquestionably'>,
#  <_sre.SRE_Match object; span=(14, 23), match='devotedly'>,
#  <_sre.SRE_Match object; span=(15, 24), match='instantly'>,
#  <_sre.SRE_Match object; span=(38, 50), match='monotonously'>,
#  <_sre.SRE_Match object; span=(21, 33), match='resoundingly'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(46, 54), match='possibly'>,
#  <_sre.SRE_Match object; span=(15, 19), match='only'>,
#  <_sre.SRE_Match object; span=(25, 37), match='marvellously'>,
#  <_sre.SRE_Match object; span=(48, 58), match='thoroughly'>,
#  <_sre.SRE_Match object; span=(39, 50), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(30, 36), match='kindly'>,
#  <_sre.SRE_Match object; span=(6, 14), match='suddenly'>,
#  <_sre.SRE_Match object; span=(40, 52), match='unfrequently'>,
#  <_sre.SRE_Match object; span=(51, 60), match='specially'>,
#  <_sre.SRE_Match object; span=(36, 40), match='only'>,
#  <_sre.SRE_Match object; span=(26, 33), match='angrily'>,
#  <_sre.SRE_Match object; span=(41, 50), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='carefully'>,
#  <_sre.SRE_Match object; span=(48, 57), match='carefully'>,
#  <_sre.SRE_Match object; span=(9, 17), match='suddenly'>,
#  <_sre.SRE_Match object; span=(30, 39), match='instantly'>,
#  <_sre.SRE_Match object; span=(26, 33), match='quickly'>,
#  <_sre.SRE_Match object; span=(12, 16), match='only'>,
#  <_sre.SRE_Match object; span=(26, 32), match='slowly'>,
#  <_sre.SRE_Match object; span=(12, 18), match='surely'>,
#  <_sre.SRE_Match object; span=(49, 55), match='mostly'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(23, 30), match='usually'>,
#  <_sre.SRE_Match object; span=(4, 15), match='fortnightly'>,
#  <_sre.SRE_Match object; span=(22, 29), match='rapidly'>,
#  <_sre.SRE_Match object; span=(19, 26), match='ignobly'>,
#  <_sre.SRE_Match object; span=(32, 42), match='charmingly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='similarly'>,
#  <_sre.SRE_Match object; span=(22, 27), match='truly'>,
#  <_sre.SRE_Match object; span=(43, 48), match='truly'>,
#  <_sre.SRE_Match object; span=(61, 66), match='truly'>,
#  <_sre.SRE_Match object; span=(30, 34), match='only'>,
#  <_sre.SRE_Match object; span=(23, 29), match='slowly'>,
#  <_sre.SRE_Match object; span=(25, 37), match='consequently'>,
#  <_sre.SRE_Match object; span=(41, 47), match='family'>,
#  <_sre.SRE_Match object; span=(31, 42), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='worldly'>,
#  <_sre.SRE_Match object; span=(51, 58), match='totally'>,
#  <_sre.SRE_Match object; span=(33, 41), match='horribly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='nearly'>,
#  <_sre.SRE_Match object; span=(4, 15), match='immediately'>,
#  <_sre.SRE_Match object; span=(44, 51), match='earthly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='courtly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='goodly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='highly'>,
#  <_sre.SRE_Match object; span=(47, 50), match='fly'>,
#  <_sre.SRE_Match object; span=(44, 55), match='accordingly'>,
#  <_sre.SRE_Match object; span=(17, 26), match='perfectly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='eternally'>,
#  <_sre.SRE_Match object; span=(32, 44), match='artificially'>,
#  <_sre.SRE_Match object; span=(22, 28), match='surely'>,
#  <_sre.SRE_Match object; span=(30, 39), match='languidly'>,
#  <_sre.SRE_Match object; span=(34, 42), match='possibly'>,
#  <_sre.SRE_Match object; span=(59, 66), match='affably'>,
#  <_sre.SRE_Match object; span=(45, 51), match='slowly'>,
#  <_sre.SRE_Match object; span=(28, 35), match='quietly'>,
#  <_sre.SRE_Match object; span=(31, 41), match='handsomely'>,
#  <_sre.SRE_Match object; span=(30, 37), match='clearly'>,
#  <_sre.SRE_Match object; span=(14, 25), match='beautifully'>,
#  <_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(58, 70), match='occasionally'>,
#  <_sre.SRE_Match object; span=(39, 45), match='barely'>,
#  <_sre.SRE_Match object; span=(49, 57), match='probably'>,
#  <_sre.SRE_Match object; span=(40, 46), match='calmly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='unearthly'>,
#  <_sre.SRE_Match object; span=(59, 65), match='gently'>,
#  <_sre.SRE_Match object; span=(8, 15), match='happily'>,
#  <_sre.SRE_Match object; span=(36, 48), match='accidentally'>,
#  <_sre.SRE_Match object; span=(9, 17), match='suddenly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='smoothly'>,
#  <_sre.SRE_Match object; span=(9, 18), match='willingly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(0, 8), match='steadily'>,
#  <_sre.SRE_Match object; span=(0, 11), match='unwillingly'>,
#  <_sre.SRE_Match object; span=(23, 34), match='brilliantly'>,
#  <_sre.SRE_Match object; span=(1, 9), match='directly'>,
#  <_sre.SRE_Match object; span=(9, 16), match='quickly'>,
#  <_sre.SRE_Match object; span=(26, 30), match='only'>,
#  <_sre.SRE_Match object; span=(8, 14), match='merely'>,
#  <_sre.SRE_Match object; span=(28, 35), match='fixedly'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='promptly'>,
#  <_sre.SRE_Match object; span=(41, 49), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='Gradually'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quietly'>,
#  <_sre.SRE_Match object; span=(18, 28), match='dreadfully'>,
#  <_sre.SRE_Match object; span=(53, 60), match='quickly'>,
#  <_sre.SRE_Match object; span=(15, 23), match='tenderly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quickly'>,
#  <_sre.SRE_Match object; span=(63, 70), match='rapidly'>,
#  <_sre.SRE_Match object; span=(25, 36), match='impartially'>,
#  <_sre.SRE_Match object; span=(34, 46), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(21, 27), match='calmly'>,
#  <_sre.SRE_Match object; span=(40, 47), match='briskly'>,
#  <_sre.SRE_Match object; span=(20, 25), match='early'>,
#  <_sre.SRE_Match object; span=(9, 16), match='rapidly'>,
#  <_sre.SRE_Match object; span=(32, 39), match='courtly'>,
#  <_sre.SRE_Match object; span=(49, 56), match='clearly'>,
#  <_sre.SRE_Match object; span=(5, 14), match='expressly'>,
#  <_sre.SRE_Match object; span=(32, 42), match='pleasantly'>,
#  <_sre.SRE_Match object; span=(38, 45), match='sweetly'>,
#  <_sre.SRE_Match object; span=(43, 55), match='indefinitely'>,
#  <_sre.SRE_Match object; span=(14, 20), match='family'>,
#  <_sre.SRE_Match object; span=(20, 27), match='happily'>,
#  <_sre.SRE_Match object; span=(19, 26), match='happily'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(9, 22), match='comparatively'>,
#  <_sre.SRE_Match object; span=(3, 12), match='elegantly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='gloomily'>,
#  <_sre.SRE_Match object; span=(60, 66), match='family'>,
#  <_sre.SRE_Match object; span=(35, 41), match='family'>,
#  <_sre.SRE_Match object; span=(4, 11), match='lightly'>,
#  <_sre.SRE_Match object; span=(5, 17), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(21, 25), match='only'>,
#  <_sre.SRE_Match object; span=(9, 16), match='ghastly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='family'>,
#  <_sre.SRE_Match object; span=(4, 14), match='delicately'>,
#  <_sre.SRE_Match object; span=(7, 13), match='family'>,
#  <_sre.SRE_Match object; span=(29, 36), match='equally'>,
#  <_sre.SRE_Match object; span=(0, 7), match='cruelly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quietly'>,
#  <_sre.SRE_Match object; span=(62, 67), match='sadly'>,
#  <_sre.SRE_Match object; span=(16, 24), match='scarcely'>,
#  <_sre.SRE_Match object; span=(21, 27), match='slowly'>,
#  <_sre.SRE_Match object; span=(16, 26), match='graciously'>,
#  <_sre.SRE_Match object; span=(12, 18), match='family'>,
#  <_sre.SRE_Match object; span=(0, 6), match='family'>,
#  <_sre.SRE_Match object; span=(22, 30), match='brightly'>,
#  <_sre.SRE_Match object; span=(49, 62), match='indifferently'>,
#  <_sre.SRE_Match object; span=(34, 41), match='courtly'>,
#  <_sre.SRE_Match object; span=(58, 66), match='forcibly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='handsomely'>,
#  <_sre.SRE_Match object; span=(43, 49), match='gently'>,
#  <_sre.SRE_Match object; span=(46, 52), match='softly'>,
#  <_sre.SRE_Match object; span=(35, 47), match='impenitently'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(44, 51), match='blindly'>,
#  <_sre.SRE_Match object; span=(54, 68), match='conventionally'>,
#  <_sre.SRE_Match object; span=(15, 21), match='hardly'>,
#  <_sre.SRE_Match object; span=(14, 21), match='blindly'>,
#  <_sre.SRE_Match object; span=(47, 54), match='usually'>,
#  <_sre.SRE_Match object; span=(18, 25), match='soundly'>,
#  <_sre.SRE_Match object; span=(59, 66), match='ghostly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='rarely'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(19, 25), match='Surely'>,
#  <_sre.SRE_Match object; span=(57, 64), match='hastily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='stupidly'>,
#  <_sre.SRE_Match object; span=(38, 44), match='highly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='suddenly'>,
#  <_sre.SRE_Match object; span=(44, 50), match='easily'>,
#  <_sre.SRE_Match object; span=(14, 23), match='unusually'>,
#  <_sre.SRE_Match object; span=(16, 22), match='mostly'>,
#  <_sre.SRE_Match object; span=(8, 18), match='invariably'>,
#  <_sre.SRE_Match object; span=(35, 43), match='tenderly'>,
#  <_sre.SRE_Match object; span=(19, 25), match='lately'>,
#  <_sre.SRE_Match object; span=(37, 46), match='gradually'>,
#  <_sre.SRE_Match object; span=(11, 21), match='frequently'>,
#  <_sre.SRE_Match object; span=(19, 26), match='equably'>,
#  <_sre.SRE_Match object; span=(19, 25), match='coldly'>,
#  <_sre.SRE_Match object; span=(25, 38), match='deferentially'>,
#  <_sre.SRE_Match object; span=(0, 9), match='earnestly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='fondly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='dearly'>,
#  <_sre.SRE_Match object; span=(60, 69), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(25, 37), match='respectfully'>,
#  <_sre.SRE_Match object; span=(7, 12), match='early'>,
#  <_sre.SRE_Match object; span=(16, 22), match='hardly'>,
#  <_sre.SRE_Match object; span=(39, 49), match='mournfully'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(22, 28), match='coldly'>,
#  <_sre.SRE_Match object; span=(44, 53), match='evidently'>,
#  <_sre.SRE_Match object; span=(16, 25), match='feelingly'>,
#  <_sre.SRE_Match object; span=(60, 66), match='nearly'>,
#  <_sre.SRE_Match object; span=(16, 23), match='equally'>,
#  <_sre.SRE_Match object; span=(38, 46), match='modestly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(57, 63), match='likely'>,
#  <_sre.SRE_Match object; span=(43, 54), match='immediately'>,
#  <_sre.SRE_Match object; span=(27, 33), match='purely'>,
#  <_sre.SRE_Match object; span=(35, 45), match='gratefully'>,
#  <_sre.SRE_Match object; span=(44, 50), match='really'>,
#  <_sre.SRE_Match object; span=(40, 46), match='slowly'>,
#  <_sre.SRE_Match object; span=(40, 48), match='slightly'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(39, 47), match='directly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='lightly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='softly'>,
#  <_sre.SRE_Match object; span=(18, 27), match='presently'>,
#  <_sre.SRE_Match object; span=(16, 23), match='heavily'>,
#  <_sre.SRE_Match object; span=(31, 41), match='handsomely'>,
#  <_sre.SRE_Match object; span=(21, 36), match='correspondingly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='portly'>,
#  <_sre.SRE_Match object; span=(14, 21), match='usually'>,
#  <_sre.SRE_Match object; span=(51, 57), match='slowly'>,
#  <_sre.SRE_Match object; span=(37, 47), match='boastfully'>,
#  <_sre.SRE_Match object; span=(0, 5), match='bully'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Certainly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='rapidly'>,
#  <_sre.SRE_Match object; span=(53, 59), match='easily'>,
#  <_sre.SRE_Match object; span=(47, 53), match='really'>,
#  <_sre.SRE_Match object; span=(44, 50), match='really'>,
#  <_sre.SRE_Match object; span=(0, 7), match='clearly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='worldly'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(15, 28), match='unaccountably'>,
#  <_sre.SRE_Match object; span=(0, 13), match='magnificently'>,
#  <_sre.SRE_Match object; span=(51, 65), match='confidentially'>,
#  <_sre.SRE_Match object; span=(12, 21), match='dubiously'>,
#  <_sre.SRE_Match object; span=(62, 70), match='friendly'>,
#  <_sre.SRE_Match object; span=(55, 61), match='really'>,
#  <_sre.SRE_Match object; span=(0, 10), match='internally'>,
#  <_sre.SRE_Match object; span=(0, 11), match='perceptibly'>,
#  <_sre.SRE_Match object; span=(56, 68), match='forensically'>,
#  <_sre.SRE_Match object; span=(10, 20), match='infinitely'>,
#  <_sre.SRE_Match object; span=(52, 58), match='mildly'>,
#  <_sre.SRE_Match object; span=(7, 14), match='exactly'>,
#  <_sre.SRE_Match object; span=(44, 59), match='disrespectfully'>,
#  <_sre.SRE_Match object; span=(63, 70), match='usually'>,
#  <_sre.SRE_Match object; span=(53, 61), match='probably'>,
#  <_sre.SRE_Match object; span=(47, 59), match='deliberately'>,
#  <_sre.SRE_Match object; span=(55, 64), match='correctly'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(41, 48), match='quickly'>,
#  <_sre.SRE_Match object; span=(28, 34), match='family'>,
#  <_sre.SRE_Match object; span=(0, 9), match='expressly'>,
#  <_sre.SRE_Match object; span=(13, 17), match='only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='popularly'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(35, 41), match='coldly'>,
#  <_sre.SRE_Match object; span=(9, 15), match='family'>,
#  <_sre.SRE_Match object; span=(60, 67), match='worldly'>,
#  <_sre.SRE_Match object; span=(60, 67), match='worldly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='hardly'>,
#  <_sre.SRE_Match object; span=(18, 24), match='really'>,
#  <_sre.SRE_Match object; span=(53, 61), match='stupidly'>,
#  <_sre.SRE_Match object; span=(43, 52), match='certainly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='rarely'>,
#  <_sre.SRE_Match object; span=(11, 18), match='vaguely'>,
#  <_sre.SRE_Match object; span=(32, 40), match='scantily'>,
#  <_sre.SRE_Match object; span=(10, 16), match='gently'>,
#  <_sre.SRE_Match object; span=(55, 63), match='steadily'>,
#  <_sre.SRE_Match object; span=(46, 54), match='modestly'>,
#  <_sre.SRE_Match object; span=(12, 16), match='idly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='fervently'>,
#  <_sre.SRE_Match object; span=(14, 20), match='gently'>,
#  <_sre.SRE_Match object; span=(49, 59), match='mournfully'>,
#  <_sre.SRE_Match object; span=(0, 9), match='outwardly'>,
#  <_sre.SRE_Match object; span=(5, 13), match='tenderly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='grisly'>,
#  <_sre.SRE_Match object; span=(25, 31), match='mostly'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(28, 39), match='incessantly'>,
#  <_sre.SRE_Match object; span=(28, 37), match='Naturally'>,
#  <_sre.SRE_Match object; span=(37, 44), match='greatly'>,
#  <_sre.SRE_Match object; span=(37, 40), match='Cly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='loudly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='closely'>,
#  <_sre.SRE_Match object; span=(37, 46), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(45, 56), match='immediately'>,
#  <_sre.SRE_Match object; span=(0, 8), match='modestly'>,
#  <_sre.SRE_Match object; span=(48, 58), match='alarmingly'>,
#  <_sre.SRE_Match object; span=(25, 35), match='disorderly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='finally'>,
#  <_sre.SRE_Match object; span=(6, 9), match='Cly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='roughly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(20, 28), match='maturely'>,
#  <_sre.SRE_Match object; span=(20, 23), match='Cly'>,
#  <_sre.SRE_Match object; span=(58, 68), match='previously'>,
#  <_sre.SRE_Match object; span=(52, 64), match='unfrequently'>,
#  <_sre.SRE_Match object; span=(46, 53), match='briskly'>,
#  <_sre.SRE_Match object; span=(44, 52), match='sullenly'>,
#  <_sre.SRE_Match object; span=(60, 64), match='ugly'>,
#  <_sre.SRE_Match object; span=(13, 16), match='fly'>,
#  <_sre.SRE_Match object; span=(21, 32), match='affectingly'>,
#  <_sre.SRE_Match object; span=(47, 53), match='family'>,
#  <_sre.SRE_Match object; span=(6, 12), match='nearly'>,
#  <_sre.SRE_Match object; span=(23, 27), match='only'>,
#  <_sre.SRE_Match object; span=(0, 6), match='lonely'>,
#  <_sre.SRE_Match object; span=(0, 8), match='silently'>,
#  <_sre.SRE_Match object; span=(6, 12), match='nimbly'>,
#  <_sre.SRE_Match object; span=(64, 70), match='softly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='Presently'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(19, 32), match='perseveringly'>,
#  <_sre.SRE_Match object; span=(62, 68), match='highly'>,
#  <_sre.SRE_Match object; span=(56, 65), match='cunningly'>,
#  <_sre.SRE_Match object; span=(46, 57), match='incessantly'>,
#  <_sre.SRE_Match object; span=(4, 10), match='family'>,
#  <_sre.SRE_Match object; span=(25, 34), match='similarly'>,
#  <_sre.SRE_Match object; span=(49, 55), match='lively'>,
#  <_sre.SRE_Match object; span=(21, 26), match='early'>,
#  <_sre.SRE_Match object; span=(61, 70), match='unusually'>,
#  <_sre.SRE_Match object; span=(5, 10), match='early'>,
#  <_sre.SRE_Match object; span=(63, 68), match='early'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(0, 8), match='musingly'>,
#  <_sre.SRE_Match object; span=(26, 34), match='formerly'>,
#  <_sre.SRE_Match object; span=(30, 36), match='singly'>,
#  <_sre.SRE_Match object; span=(26, 35), match='carefully'>,
#  <_sre.SRE_Match object; span=(54, 59), match='reply'>,
#  <_sre.SRE_Match object; span=(60, 66), match='slowly'>,
#  <_sre.SRE_Match object; span=(50, 56), match='softly'>,
#  <_sre.SRE_Match object; span=(11, 20), match='unluckily'>,
#  <_sre.SRE_Match object; span=(7, 14), match='vividly'>,
#  <_sre.SRE_Match object; span=(24, 36), match='consequently'>,
#  <_sre.SRE_Match object; span=(32, 38), match='darkly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='equally'>,
#  <_sre.SRE_Match object; span=(37, 45), match='Formerly'>,
#  <_sre.SRE_Match object; span=(50, 57), match='sternly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='strikingly'>,
#  <_sre.SRE_Match object; span=(44, 53), match='certainly'>,
#  <_sre.SRE_Match object; span=(29, 36), match='finally'>,
#  <_sre.SRE_Match object; span=(60, 68), match='actually'>,
#  <_sre.SRE_Match object; span=(20, 30), match='faithfully'>,
#  <_sre.SRE_Match object; span=(8, 17), match='willingly'>,
#  <_sre.SRE_Match object; span=(6, 12), match='easily'>,
#  <_sre.SRE_Match object; span=(28, 39), match='judiciously'>,
#  <_sre.SRE_Match object; span=(22, 33), match='Judiciously'>,
#  <_sre.SRE_Match object; span=(49, 55), match='easily'>,
#  <_sre.SRE_Match object; span=(43, 53), match='constantly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='expressly'>,
#  <_sre.SRE_Match object; span=(49, 57), match='brightly'>,
#  <_sre.SRE_Match object; span=(27, 37), match='infallibly'>,
#  <_sre.SRE_Match object; span=(43, 55), match='additionally'>,
#  <_sre.SRE_Match object; span=(19, 31), match='additionally'>,
#  <_sre.SRE_Match object; span=(43, 53), match='composedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='mightily'>,
#  <_sre.SRE_Match object; span=(46, 55), match='elegantly'>,
#  <_sre.SRE_Match object; span=(12, 22), match='handsomely'>,
#  <_sre.SRE_Match object; span=(34, 44), match='absolutely'>,
#  <_sre.SRE_Match object; span=(5, 8), match='fly'>,
#  <_sre.SRE_Match object; span=(36, 48), match='reflectively'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(24, 38), match='superciliously'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(58, 61), match='fly'>,
#  <_sre.SRE_Match object; span=(51, 59), match='amicably'>,
#  <_sre.SRE_Match object; span=(16, 22), match='slowly'>,
#  <_sre.SRE_Match object; span=(10, 15), match='analy'>,
#  <_sre.SRE_Match object; span=(14, 23), match='naturally'>,
#  <_sre.SRE_Match object; span=(23, 37), match='affectionately'>,
#  <_sre.SRE_Match object; span=(24, 31), match='finally'>,
#  <_sre.SRE_Match object; span=(30, 40), match='accurately'>,
#  <_sre.SRE_Match object; span=(17, 26), match='generally'>,
#  <_sre.SRE_Match object; span=(36, 47), match='immediately'>,
#  <_sre.SRE_Match object; span=(9, 16), match='finally'>,
#  <_sre.SRE_Match object; span=(43, 55), match='complacently'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(42, 48), match='firmly'>,
#  <_sre.SRE_Match object; span=(31, 41), match='composedly'>,
#  <_sre.SRE_Match object; span=(26, 38), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(10, 19), match='certainly'>,
#  <_sre.SRE_Match object; span=(25, 36), match='assiduously'>,
#  <_sre.SRE_Match object; span=(36, 45), match='gradually'>,
#  <_sre.SRE_Match object; span=(18, 27), match='generally'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Decidedly'>,
#  <_sre.SRE_Match object; span=(18, 24), match='nimbly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='decidedly'>,
#  <_sre.SRE_Match object; span=(16, 26), match='separately'>,
#  <_sre.SRE_Match object; span=(53, 59), match='deftly'>,
#  <_sre.SRE_Match object; span=(14, 23), match='certainly'>,
#  <_sre.SRE_Match object; span=(40, 52), match='occasionally'>,
#  <_sre.SRE_Match object; span=(31, 37), match='coolly'>,
#  <_sre.SRE_Match object; span=(28, 36), match='vacantly'>,
#  <_sre.SRE_Match object; span=(38, 44), match='airily'>,
#  <_sre.SRE_Match object; span=(32, 37), match='drily'>,
#  <_sre.SRE_Match object; span=(53, 63), match='profoundly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='certainly'>,
#  <_sre.SRE_Match object; span=(22, 31), match='gradually'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Perfectly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='family'>,
#  <_sre.SRE_Match object; span=(25, 33), match='steadily'>,
#  <_sre.SRE_Match object; span=(39, 46), match='exactly'>,
#  <_sre.SRE_Match object; span=(7, 15), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 9), match='presently'>,
#  <_sre.SRE_Match object; span=(5, 12), match='shortly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='frightfully'>,
#  <_sre.SRE_Match object; span=(35, 41), match='surely'>,
#  <_sre.SRE_Match object; span=(8, 18), match='pleasantly'>,
#  <_sre.SRE_Match object; span=(51, 57), match='deeply'>,
#  <_sre.SRE_Match object; span=(0, 8), match='scarcely'>,
#  <_sre.SRE_Match object; span=(13, 21), match='tenderly'>,
#  <_sre.SRE_Match object; span=(7, 12), match='fully'>,
#  <_sre.SRE_Match object; span=(0, 8), match='entirely'>,
#  <_sre.SRE_Match object; span=(32, 36), match='only'>,
#  <_sre.SRE_Match object; span=(46, 55), match='perfectly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='Hardly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='fervently'>,
#  <_sre.SRE_Match object; span=(19, 27), match='solemnly'>,
#  <_sre.SRE_Match object; span=(51, 59), match='formerly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(0, 14), match='affectionately'>,
#  <_sre.SRE_Match object; span=(6, 13), match='timidly'>,
#  <_sre.SRE_Match object; span=(56, 62), match='softly'>,
#  <_sre.SRE_Match object; span=(31, 39), match='brightly'>,
#  <_sre.SRE_Match object; span=(42, 54), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(32, 39), match='lightly'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(8, 14), match='highly'>,
#  <_sre.SRE_Match object; span=(30, 39), match='beamingly'>,
#  <_sre.SRE_Match object; span=(52, 64), match='unhandsomely'>,
#  <_sre.SRE_Match object; span=(54, 64), match='soothingly'>,
#  <_sre.SRE_Match object; span=(32, 45), match='comparatively'>,
#  <_sre.SRE_Match object; span=(18, 24), match='deadly'>,
#  <_sre.SRE_Match object; span=(55, 61), match='lately'>,
#  <_sre.SRE_Match object; span=(0, 7), match='happily'>,
#  <_sre.SRE_Match object; span=(40, 45), match='newly'>,
#  <_sre.SRE_Match object; span=(31, 37), match='gently'>,
#  <_sre.SRE_Match object; span=(9, 18), match='naturally'>,
#  <_sre.SRE_Match object; span=(43, 51), match='drearily'>,
#  <_sre.SRE_Match object; span=(19, 28), match='presently'>,
#  <_sre.SRE_Match object; span=(46, 57), match='inquiringly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='impatiently'>,
#  <_sre.SRE_Match object; span=(24, 36), match='mechanically'>,
#  <_sre.SRE_Match object; span=(34, 38), match='only'>,
#  <_sre.SRE_Match object; span=(39, 48), match='furtively'>,
#  <_sre.SRE_Match object; span=(28, 42), match='professionally'>,
#  <_sre.SRE_Match object; span=(0, 11), match='attentively'>,
#  <_sre.SRE_Match object; span=(44, 50), match='merely'>,
#  <_sre.SRE_Match object; span=(47, 54), match='finally'>,
#  <_sre.SRE_Match object; span=(44, 54), match='cheerfully'>,
#  <_sre.SRE_Match object; span=(15, 20), match='reply'>,
#  <_sre.SRE_Match object; span=(44, 54), match='confusedly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='quietly'>,
#  <_sre.SRE_Match object; span=(28, 37), match='precisely'>,
#  <_sre.SRE_Match object; span=(25, 33), match='friendly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='slowly'>,
#  <_sre.SRE_Match object; span=(33, 43), match='dreadfully'>,
#  <_sre.SRE_Match object; span=(32, 42), match='distinctly'>,
#  <_sre.SRE_Match object; span=(10, 16), match='calmly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='giddily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='actually'>,
#  <_sre.SRE_Match object; span=(48, 53), match='early'>,
#  <_sre.SRE_Match object; span=(27, 37), match='cautiously'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(51, 60), match='purposely'>,
#  <_sre.SRE_Match object; span=(27, 36), match='evidently'>,
#  <_sre.SRE_Match object; span=(29, 39), match='composedly'>,
#  <_sre.SRE_Match object; span=(51, 60), match='feelingly'>,
#  <_sre.SRE_Match object; span=(49, 55), match='deeply'>,
#  <_sre.SRE_Match object; span=(41, 52), match='attentively'>,
#  <_sre.SRE_Match object; span=(49, 63), match='affectionately'>,
#  <_sre.SRE_Match object; span=(32, 44), match='particularly'>,
#  <_sre.SRE_Match object; span=(35, 43), match='publicly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='completely'>,
#  <_sre.SRE_Match object; span=(56, 66), match='constantly'>,
#  <_sre.SRE_Match object; span=(17, 30), match='unfortunately'>,
#  <_sre.SRE_Match object; span=(49, 59), match='distinctly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='collectedly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='originally'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(16, 20), match='rely'>,
#  <_sre.SRE_Match object; span=(59, 66), match='clearly'>,
#  <_sre.SRE_Match object; span=(35, 43), match='sensibly'>,
#  <_sre.SRE_Match object; span=(25, 31), match='gently'>,
#  <_sre.SRE_Match object; span=(47, 54), match='vividly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='desolately'>,
#  <_sre.SRE_Match object; span=(50, 57), match='vaguely'>,
#  <_sre.SRE_Match object; span=(54, 63), match='unusually'>,
#  <_sre.SRE_Match object; span=(40, 46), match='easily'>,
#  <_sre.SRE_Match object; span=(32, 38), match='likely'>,
#  <_sre.SRE_Match object; span=(32, 38), match='slowly'>,
#  <_sre.SRE_Match object; span=(8, 14), match='really'>,
#  <_sre.SRE_Match object; span=(13, 20), match='happily'>,
#  <_sre.SRE_Match object; span=(12, 24), match='unexpectedly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='nervously'>,
#  <_sre.SRE_Match object; span=(57, 66), match='nervously'>,
#  <_sre.SRE_Match object; span=(36, 48), match='consistently'>,
#  <_sre.SRE_Match object; span=(53, 64), match='frightfully'>,
#  <_sre.SRE_Match object; span=(13, 17), match='only'>,
#  <_sre.SRE_Match object; span=(35, 46), match='tremulously'>,
#  <_sre.SRE_Match object; span=(23, 27), match='only'>,
#  <_sre.SRE_Match object; span=(12, 19), match='readily'>,
#  <_sre.SRE_Match object; span=(40, 49), match='perfectly'>,
#  <_sre.SRE_Match object; span=(4, 14), match='previously'>,
#  <_sre.SRE_Match object; span=(44, 54), match='previously'>,
#  <_sre.SRE_Match object; span=(11, 16), match='newly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='scarcely'>,
#  <_sre.SRE_Match object; span=(4, 12), match='bitterly'>,
#  <_sre.SRE_Match object; span=(9, 17), match='strongly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='scarcely'>,
#  <_sre.SRE_Match object; span=(29, 35), match='busily'>,
#  <_sre.SRE_Match object; span=(13, 23), match='tranquilly'>,
#  <_sre.SRE_Match object; span=(47, 56), match='perfectly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='slowly'>,
#  <_sre.SRE_Match object; span=(31, 39), match='scarcely'>,
#  <_sre.SRE_Match object; span=(40, 45), match='early'>,
#  <_sre.SRE_Match object; span=(7, 13), match='busily'>,
#  <_sre.SRE_Match object; span=(38, 46), match='friendly'>,
#  <_sre.SRE_Match object; span=(28, 34), match='unruly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='wholly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='comically'>,
#  <_sre.SRE_Match object; span=(13, 19), match='rarely'>,
#  <_sre.SRE_Match object; span=(14, 20), match='really'>,
#  <_sre.SRE_Match object; span=(12, 19), match='usually'>,
#  <_sre.SRE_Match object; span=(0, 9), match='unhappily'>,
#  <_sre.SRE_Match object; span=(22, 34), match='particularly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='delicately'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(30, 36), match='surely'>,
#  <_sre.SRE_Match object; span=(18, 28), match='originally'>,
#  <_sre.SRE_Match object; span=(37, 45), match='suitably'>,
#  <_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(0, 10), match='menacingly'>,
#  <_sre.SRE_Match object; span=(20, 24), match='July'>,
#  <_sre.SRE_Match object; span=(5, 13), match='actually'>,
#  <_sre.SRE_Match object; span=(3, 13), match='positively'>,
#  <_sre.SRE_Match object; span=(34, 40), match='really'>,
#  <_sre.SRE_Match object; span=(16, 23), match='soundly'>,
#  <_sre.SRE_Match object; span=(61, 65), match='Only'>,
#  <_sre.SRE_Match object; span=(30, 36), match='easily'>,
#  <_sre.SRE_Match object; span=(34, 46), match='convulsively'>,
#  <_sre.SRE_Match object; span=(25, 34), match='crookedly'>,
#  <_sre.SRE_Match object; span=(20, 29), match='variously'>,
#  <_sre.SRE_Match object; span=(15, 21), match='doubly'>,
#  <_sre.SRE_Match object; span=(60, 65), match='dimly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='nearly'>,
#  <_sre.SRE_Match object; span=(10, 20), match='faithfully'>,
#  <_sre.SRE_Match object; span=(52, 61), match='evidently'>,
#  <_sre.SRE_Match object; span=(44, 56), match='occasionally'>,
#  <_sre.SRE_Match object; span=(7, 17), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(15, 21), match='slowly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='heavily'>,
#  <_sre.SRE_Match object; span=(56, 60), match='only'>,
#  <_sre.SRE_Match object; span=(56, 63), match='heavily'>,
#  <_sre.SRE_Match object; span=(19, 25), match='slowly'>,
#  <_sre.SRE_Match object; span=(49, 56), match='closely'>,
#  <_sre.SRE_Match object; span=(45, 53), match='greedily'>,
#  <_sre.SRE_Match object; span=(35, 41), match='deeply'>,
#  <_sre.SRE_Match object; span=(36, 46), match='wrathfully'>,
#  <_sre.SRE_Match object; span=(16, 24), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(54, 65), match='turbulently'>,
#  <_sre.SRE_Match object; span=(11, 18), match='fixedly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='suddenly'>,
#  <_sre.SRE_Match object; span=(40, 46), match='loudly'>,
#  <_sre.SRE_Match object; span=(54, 58), match='July'>,
#  <_sre.SRE_Match object; span=(0, 6), match='easily'>,
#  <_sre.SRE_Match object; span=(32, 36), match='only'>,
#  <_sre.SRE_Match object; span=(57, 66), match='extremely'>,
#  <_sre.SRE_Match object; span=(25, 37), match='portentously'>,
#  <_sre.SRE_Match object; span=(15, 23), match='mightily'>,
#  <_sre.SRE_Match object; span=(48, 56), match='suddenly'>,
#  <_sre.SRE_Match object; span=(29, 43), match='contemptuously'>,
#  <_sre.SRE_Match object; span=(0, 11), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(2, 11), match='Instantly'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(14, 18), match='ugly'>,
#  <_sre.SRE_Match object; span=(13, 24), match='immediately'>,
#  <_sre.SRE_Match object; span=(28, 37), match='Similarly'>,
#  <_sre.SRE_Match object; span=(35, 42), match='readily'>,
#  <_sre.SRE_Match object; span=(50, 56), match='kindly'>,
#  <_sre.SRE_Match object; span=(20, 28), match='directly'>,
#  <_sre.SRE_Match object; span=(21, 33), match='surprisingly'>,
#  <_sre.SRE_Match object; span=(15, 23), match='directly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='deadly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='silently'>,
#  <_sre.SRE_Match object; span=(27, 39), match='passionately'>,
#  <_sre.SRE_Match object; span=(18, 25), match='sternly'>,
#  <_sre.SRE_Match object; span=(34, 43), match='patiently'>,
#  <_sre.SRE_Match object; span=(36, 45), match='Gradually'>,
#  <_sre.SRE_Match object; span=(32, 38), match='gently'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(31, 36), match='daily'>,
#  <_sre.SRE_Match object; span=(14, 22), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 9), match='expressly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='surely'>,
#  <_sre.SRE_Match object; span=(61, 67), match='lonely'>,
#  ...]

# %%
a=list(filter(None,results))
a
# Out:
# [<_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(48, 56), match='recently'>,
#  <_sre.SRE_Match object; span=(52, 56), match='only'>,
#  <_sre.SRE_Match object; span=(21, 35), match='supernaturally'>,
#  <_sre.SRE_Match object; span=(33, 40), match='earthly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='likely'>,
#  <_sre.SRE_Match object; span=(46, 52), match='likely'>,
#  <_sre.SRE_Match object; span=(30, 41), match='unceasingly'>,
#  <_sre.SRE_Match object; span=(24, 32), match='scarcely'>,
#  <_sre.SRE_Match object; span=(14, 22), match='publicly'>,
#  <_sre.SRE_Match object; span=(32, 41), match='gallantly'>,
#  <_sre.SRE_Match object; span=(41, 49), match='strongly'>,
#  <_sre.SRE_Match object; span=(29, 38), match='violently'>,
#  <_sre.SRE_Match object; span=(17, 26), match='unusually'>,
#  <_sre.SRE_Match object; span=(27, 36), match='intensely'>,
#  <_sre.SRE_Match object; span=(32, 39), match='visibly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='instantly'>,
#  <_sre.SRE_Match object; span=(31, 37), match='nimbly'>,
#  <_sre.SRE_Match object; span=(44, 51), match='audibly'>,
#  <_sre.SRE_Match object; span=(49, 58), match='furiously'>,
#  <_sre.SRE_Match object; span=(15, 23), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 13), match='distrustfully'>,
#  <_sre.SRE_Match object; span=(56, 62), match='mildly'>,
#  <_sre.SRE_Match object; span=(36, 43), match='swiftly'>,
#  <_sre.SRE_Match object; span=(20, 31), match='immediately'>,
#  <_sre.SRE_Match object; span=(42, 50), match='hoarsely'>,
#  <_sre.SRE_Match object; span=(40, 46), match='slowly'>,
#  <_sre.SRE_Match object; span=(9, 15), match='curtly'>,
#  <_sre.SRE_Match object; span=(50, 63), match='expeditiously'>,
#  <_sre.SRE_Match object; span=(42, 54), match='occasionally'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(9, 15), match='softly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(0, 7), match='heavily'>,
#  <_sre.SRE_Match object; span=(13, 19), match='darkly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='vainly'>,
#  <_sre.SRE_Match object; span=(27, 34), match='exactly'>,
#  <_sre.SRE_Match object; span=(50, 56), match='singly'>,
#  <_sre.SRE_Match object; span=(33, 39), match='nearly'>,
#  <_sre.SRE_Match object; span=(61, 65), match='only'>,
#  <_sre.SRE_Match object; span=(21, 29), match='raggedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='jaggedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='strongly'>,
#  <_sre.SRE_Match object; span=(11, 16), match='dimly'>,
#  <_sre.SRE_Match object; span=(47, 53), match='feebly'>,
#  <_sre.SRE_Match object; span=(43, 54), match='principally'>,
#  <_sre.SRE_Match object; span=(29, 40), match='prematurely'>,
#  <_sre.SRE_Match object; span=(21, 26), match='reply'>,
#  <_sre.SRE_Match object; span=(48, 56), match='suddenly'>,
#  <_sre.SRE_Match object; span=(50, 57), match='ghostly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='securely'>,
#  <_sre.SRE_Match object; span=(54, 64), match='distinctly'>,
#  <_sre.SRE_Match object; span=(20, 32), match='successfully'>,
#  <_sre.SRE_Match object; span=(26, 30), match='only'>,
#  <_sre.SRE_Match object; span=(27, 33), match='nicely'>,
#  <_sre.SRE_Match object; span=(50, 57), match='heavily'>,
#  <_sre.SRE_Match object; span=(0, 12), match='Consequently'>,
#  <_sre.SRE_Match object; span=(7, 15), match='formally'>,
#  <_sre.SRE_Match object; span=(7, 14), match='orderly'>,
#  <_sre.SRE_Match object; span=(19, 29), match='habitually'>,
#  <_sre.SRE_Match object; span=(20, 31), match='principally'>,
#  <_sre.SRE_Match object; span=(5, 11), match='easily'>,
#  <_sre.SRE_Match object; span=(62, 66), match='only'>,
#  <_sre.SRE_Match object; span=(16, 22), match='wildly'>,
#  <_sre.SRE_Match object; span=(43, 48), match='madly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='particularly'>,
#  <_sre.SRE_Match object; span=(57, 70), match='unaccountably'>,
#  <_sre.SRE_Match object; span=(4, 10), match='busily'>,
#  <_sre.SRE_Match object; span=(29, 36), match='elderly'>,
#  <_sre.SRE_Match object; span=(19, 28), match='extremely'>,
#  <_sre.SRE_Match object; span=(10, 21), match='immediately'>,
#  <_sre.SRE_Match object; span=(24, 32), match='gloomily'>,
#  <_sre.SRE_Match object; span=(43, 49), match='merely'>,
#  <_sre.SRE_Match object; span=(51, 58), match='heavily'>,
#  <_sre.SRE_Match object; span=(37, 43), match='highly'>,
#  <_sre.SRE_Match object; span=(45, 55), match='gratefully'>,
#  <_sre.SRE_Match object; span=(0, 9), match='naturally'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Naturally'>,
#  <_sre.SRE_Match object; span=(48, 60), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(29, 34), match='truly'>,
#  <_sre.SRE_Match object; span=(12, 20), match='wilfully'>,
#  <_sre.SRE_Match object; span=(63, 70), match='usually'>,
#  <_sre.SRE_Match object; span=(49, 57), match='entirely'>,
#  <_sre.SRE_Match object; span=(0, 9), match='curiously'>,
#  <_sre.SRE_Match object; span=(59, 63), match='only'>,
#  <_sre.SRE_Match object; span=(49, 60), match='confidingly'>,
#  <_sre.SRE_Match object; span=(48, 53), match='truly'>,
#  <_sre.SRE_Match object; span=(36, 41), match='daily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(13, 24), match='collectedly'>,
#  <_sre.SRE_Match object; span=(24, 33), match='intensely'>,
#  <_sre.SRE_Match object; span=(30, 39), match='intensely'>,
#  <_sre.SRE_Match object; span=(64, 70), match='kindly'>,
#  <_sre.SRE_Match object; span=(10, 18), match='directly'>,
#  <_sre.SRE_Match object; span=(12, 18), match='gently'>,
#  <_sre.SRE_Match object; span=(23, 35), match='particularly'>,
#  <_sre.SRE_Match object; span=(45, 52), match='Greatly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='quietly'>,
#  <_sre.SRE_Match object; span=(3, 7), match='Only'>,
#  <_sre.SRE_Match object; span=(57, 67), match='designedly'>,
#  <_sre.SRE_Match object; span=(53, 59), match='openly'>,
#  <_sre.SRE_Match object; span=(2, 11), match='Perfectly'>,
#  <_sre.SRE_Match object; span=(24, 31), match='utterly'>,
#  <_sre.SRE_Match object; span=(24, 30), match='loudly'>,
#  <_sre.SRE_Match object; span=(27, 30), match='fly'>,
#  <_sre.SRE_Match object; span=(6, 12), match='really'>,
#  <_sre.SRE_Match object; span=(12, 26), match='simultaneously'>,
#  <_sre.SRE_Match object; span=(0, 6), match='softly'>,
#  <_sre.SRE_Match object; span=(32, 43), match='indignantly'>,
#  <_sre.SRE_Match object; span=(19, 30), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(5, 11), match='likely'>,
#  <_sre.SRE_Match object; span=(24, 33), match='expressly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(60, 70), match='especially'>,
#  <_sre.SRE_Match object; span=(32, 40), match='suddenly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='saintly'>,
#  <_sre.SRE_Match object; span=(10, 20), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(36, 40), match='only'>,
#  <_sre.SRE_Match object; span=(53, 59), match='rudely'>,
#  <_sre.SRE_Match object; span=(29, 40), match='gloweringly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='abruptly'>,
#  <_sre.SRE_Match object; span=(45, 49), match='only'>,
#  <_sre.SRE_Match object; span=(5, 11), match='sickly'>,
#  <_sre.SRE_Match object; span=(54, 64), match='completely'>,
#  <_sre.SRE_Match object; span=(0, 12), match='accidentally'>,
#  <_sre.SRE_Match object; span=(52, 61), match='extremely'>,
#  <_sre.SRE_Match object; span=(7, 16), match='wolfishly'>,
#  <_sre.SRE_Match object; span=(29, 41), match='deliberately'>,
#  <_sre.SRE_Match object; span=(13, 20), match='crisply'>,
#  <_sre.SRE_Match object; span=(0, 9), match='evidently'>,
#  <_sre.SRE_Match object; span=(0, 7), match='heavily'>,
#  <_sre.SRE_Match object; span=(45, 51), match='darkly'>,
#  <_sre.SRE_Match object; span=(23, 34), match='accordingly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='elderly'>,
#  <_sre.SRE_Match object; span=(64, 70), match='supply'>,
#  <_sre.SRE_Match object; span=(0, 7), match='elderly'>,
#  <_sre.SRE_Match object; span=(4, 12), match='slightly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='observantly'>,
#  <_sre.SRE_Match object; span=(56, 63), match='elderly'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='deeply'>,
#  <_sre.SRE_Match object; span=(0, 6), match='gently'>,
#  <_sre.SRE_Match object; span=(62, 68), match='slowly'>,
#  <_sre.SRE_Match object; span=(9, 16), match='greatly'>,
#  <_sre.SRE_Match object; span=(19, 25), match='sickly'>,
#  <_sre.SRE_Match object; span=(32, 41), match='carefully'>,
#  <_sre.SRE_Match object; span=(26, 31), match='reply'>,
#  <_sre.SRE_Match object; span=(34, 41), match='heavily'>,
#  <_sre.SRE_Match object; span=(38, 46), match='bitterly'>,
#  <_sre.SRE_Match object; span=(34, 38), match='only'>,
#  <_sre.SRE_Match object; span=(15, 21), match='slowly'>,
#  <_sre.SRE_Match object; span=(45, 53), match='intently'>,
#  <_sre.SRE_Match object; span=(32, 40), match='silently'>,
#  <_sre.SRE_Match object; span=(18, 24), match='likely'>,
#  <_sre.SRE_Match object; span=(38, 47), match='evidently'>,
#  <_sre.SRE_Match object; span=(49, 57), match='clumsily'>,
#  <_sre.SRE_Match object; span=(23, 30), match='heavily'>,
#  <_sre.SRE_Match object; span=(11, 17), match='slowly'>,
#  <_sre.SRE_Match object; span=(18, 26), match='securely'>,
#  <_sre.SRE_Match object; span=(5, 17), match='methodically'>,
#  <_sre.SRE_Match object; span=(24, 31), match='Finally'>,
#  <_sre.SRE_Match object; span=(42, 48), match='slowly'>,
#  <_sre.SRE_Match object; span=(50, 58), match='entirely'>,
#  <_sre.SRE_Match object; span=(26, 32), match='lonely'>,
#  <_sre.SRE_Match object; span=(59, 63), match='only'>,
#  <_sre.SRE_Match object; span=(49, 58), match='similarly'>,
#  <_sre.SRE_Match object; span=(52, 60), match='raggedly'>,
#  <_sre.SRE_Match object; span=(38, 49), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='really'>,
#  <_sre.SRE_Match object; span=(7, 18), match='unnaturally'>,
#  <_sre.SRE_Match object; span=(50, 61), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(17, 25), match='silently'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Assuredly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(43, 49), match='slowly'>,
#  <_sre.SRE_Match object; span=(30, 41), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='fixedly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='fixedly'>,
#  <_sre.SRE_Match object; span=(56, 64), match='actively'>,
#  <_sre.SRE_Match object; span=(51, 60), match='gradually'>,
#  <_sre.SRE_Match object; span=(19, 26), match='exactly'>,
#  <_sre.SRE_Match object; span=(24, 28), match='only'>,
#  <_sre.SRE_Match object; span=(0, 7), match='exactly'>,
#  <_sre.SRE_Match object; span=(14, 25), match='attentively'>,
#  <_sre.SRE_Match object; span=(48, 55), match='Finally'>,
#  <_sre.SRE_Match object; span=(0, 14), match='unquestionably'>,
#  <_sre.SRE_Match object; span=(39, 46), match='visibly'>,
#  <_sre.SRE_Match object; span=(30, 36), match='softly'>,
#  <_sre.SRE_Match object; span=(58, 67), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(24, 34), match='doubtfully'>,
#  <_sre.SRE_Match object; span=(20, 26), match='really'>,
#  <_sre.SRE_Match object; span=(43, 52), match='carefully'>,
#  <_sre.SRE_Match object; span=(51, 58), match='closely'>,
#  <_sre.SRE_Match object; span=(0, 10), match='coherently'>,
#  <_sre.SRE_Match object; span=(36, 45), match='perfectly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(9, 17), match='gloomily'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(63, 67), match='only'>,
#  <_sre.SRE_Match object; span=(6, 13), match='hastily'>,
#  <_sre.SRE_Match object; span=(10, 22), match='occasionally'>,
#  <_sre.SRE_Match object; span=(29, 39), match='invariably'>,
#  <_sre.SRE_Match object; span=(58, 65), match='readily'>,
#  <_sre.SRE_Match object; span=(3, 12), match='evidently'>,
#  <_sre.SRE_Match object; span=(52, 65), match='instinctively'>,
#  <_sre.SRE_Match object; span=(47, 51), match='Only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='miserably'>,
#  <_sre.SRE_Match object; span=(8, 19), match='immediately'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quickly'>,
#  <_sre.SRE_Match object; span=(38, 45), match='gravely'>,
#  <_sre.SRE_Match object; span=(11, 15), match='ugly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='highly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='hardly'>,
#  <_sre.SRE_Match object; span=(61, 67), match='family'>,
#  <_sre.SRE_Match object; span=(59, 64), match='newly'>,
#  <_sre.SRE_Match object; span=(15, 26), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(4, 11), match='exactly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='privately'>,
#  <_sre.SRE_Match object; span=(38, 45), match='gravely'>,
#  <_sre.SRE_Match object; span=(55, 59), match='only'>,
#  <_sre.SRE_Match object; span=(22, 35), match='spectacularly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='grisly'>,
#  <_sre.SRE_Match object; span=(32, 39), match='stately'>,
#  <_sre.SRE_Match object; span=(39, 47), match='easterly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='apparently'>,
#  <_sre.SRE_Match object; span=(50, 58), match='decently'>,
#  <_sre.SRE_Match object; span=(28, 35), match='heavily'>,
#  <_sre.SRE_Match object; span=(13, 20), match='orderly'>,
#  <_sre.SRE_Match object; span=(9, 13), match='only'>,
#  <_sre.SRE_Match object; span=(33, 37), match='only'>,
#  <_sre.SRE_Match object; span=(23, 31), match='strongly'>,
#  <_sre.SRE_Match object; span=(8, 12), match='only'>,
#  <_sre.SRE_Match object; span=(36, 47), match='religiously'>,
#  <_sre.SRE_Match object; span=(11, 18), match='greatly'>,
#  <_sre.SRE_Match object; span=(34, 40), match='merely'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Exceedingly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='scarcely'>,
#  <_sre.SRE_Match object; span=(20, 26), match='bodily'>,
#  <_sre.SRE_Match object; span=(16, 25), match='extremely'>,
#  <_sre.SRE_Match object; span=(0, 10), match='restlessly'>,
#  <_sre.SRE_Match object; span=(29, 34), match='early'>,
#  <_sre.SRE_Match object; span=(23, 35), match='deliberately'>,
#  <_sre.SRE_Match object; span=(41, 50), match='certainly'>,
#  <_sre.SRE_Match object; span=(20, 26), match='deadly'>,
#  <_sre.SRE_Match object; span=(4, 15), match='continually'>,
#  <_sre.SRE_Match object; span=(38, 52), match='systematically'>,
#  <_sre.SRE_Match object; span=(8, 15), match='quietly'>,
#  <_sre.SRE_Match object; span=(7, 11), match='only'>,
#  <_sre.SRE_Match object; span=(39, 49), match='grudgingly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='nearly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='quietly'>,
#  <_sre.SRE_Match object; span=(50, 59), match='Presently'>,
#  <_sre.SRE_Match object; span=(0, 7), match='plainly'>,
#  <_sre.SRE_Match object; span=(53, 63), match='shamefully'>,
#  <_sre.SRE_Match object; span=(0, 8), match='wickedly'>,
#  <_sre.SRE_Match object; span=(29, 41), match='circuitously'>,
#  <_sre.SRE_Match object; span=(51, 59), match='mentally'>,
#  <_sre.SRE_Match object; span=(0, 10), match='composedly'>,
#  <_sre.SRE_Match object; span=(18, 25), match='ghastly'>,
#  <_sre.SRE_Match object; span=(5, 16), match='immediately'>,
#  <_sre.SRE_Match object; span=(37, 46), match='evidently'>,
#  <_sre.SRE_Match object; span=(18, 28), match='strikingly'>,
#  <_sre.SRE_Match object; span=(33, 43), match='powerfully'>,
#  <_sre.SRE_Match object; span=(41, 47), match='slowly'>,
#  <_sre.SRE_Match object; span=(42, 50), match='steadily'>,
#  <_sre.SRE_Match object; span=(61, 68), match='happily'>,
#  <_sre.SRE_Match object; span=(14, 23), match='assuredly'>,
#  <_sre.SRE_Match object; span=(12, 20), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 10), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 10), match='unworthily'>,
#  <_sre.SRE_Match object; span=(37, 41), match='holy'>,
#  <_sre.SRE_Match object; span=(43, 53), match='habitually'>,
#  <_sre.SRE_Match object; span=(17, 27), match='positively'>,
#  <_sre.SRE_Match object; span=(9, 16), match='exactly'>,
#  <_sre.SRE_Match object; span=(41, 48), match='exactly'>,
#  <_sre.SRE_Match object; span=(45, 53), match='modestly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='precisely'>,
#  <_sre.SRE_Match object; span=(53, 62), match='Certainly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='Frequently'>,
#  <_sre.SRE_Match object; span=(53, 63), match='Positively'>,
#  <_sre.SRE_Match object; span=(30, 33), match='Cly'>,
#  <_sre.SRE_Match object; span=(50, 54), match='only'>,
#  <_sre.SRE_Match object; span=(61, 67), match='merely'>,
#  <_sre.SRE_Match object; span=(35, 47), match='particularly'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(21, 29), match='unlikely'>,
#  <_sre.SRE_Match object; span=(5, 14), match='certainly'>,
#  <_sre.SRE_Match object; span=(40, 44), match='only'>,
#  <_sre.SRE_Match object; span=(14, 22), match='untimely'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(55, 59), match='only'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Hardly'>,
#  <_sre.SRE_Match object; span=(11, 20), match='unhappily'>,
#  <_sre.SRE_Match object; span=(41, 49), match='fiercely'>,
#  <_sre.SRE_Match object; span=(44, 51), match='faintly'>,
#  <_sre.SRE_Match object; span=(17, 25), match='lovingly'>,
#  <_sre.SRE_Match object; span=(3, 11), match='Possibly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(42, 51), match='perfectly'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(5, 15), match='laughingly'>,
#  <_sre.SRE_Match object; span=(6, 14), match='strongly'>,
#  <_sre.SRE_Match object; span=(8, 21), match='unconsciously'>,
#  <_sre.SRE_Match object; span=(0, 9), match='painfully'>,
#  <_sre.SRE_Match object; span=(46, 57), match='accordingly'>,
#  <_sre.SRE_Match object; span=(12, 17), match='newly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='slovenly'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='family'>,
#  <_sre.SRE_Match object; span=(13, 19), match='likely'>,
#  <_sre.SRE_Match object; span=(11, 14), match='Cly'>,
#  <_sre.SRE_Match object; span=(46, 52), match='Lastly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='decidedly'>,
#  <_sre.SRE_Match object; span=(8, 17), match='anxiously'>,
#  <_sre.SRE_Match object; span=(19, 25), match='slowly'>,
#  <_sre.SRE_Match object; span=(56, 66), match='especially'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(44, 55), match='undoubtedly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='hardly'>,
#  <_sre.SRE_Match object; span=(60, 67), match='audibly'>,
#  <_sre.SRE_Match object; span=(33, 42), match='evidently'>,
#  <_sre.SRE_Match object; span=(16, 22), match='easily'>,
#  <_sre.SRE_Match object; span=(10, 17), match='greatly'>,
#  <_sre.SRE_Match object; span=(47, 55), match='publicly'>,
#  <_sre.SRE_Match object; span=(28, 36), match='directly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='naturally'>,
#  <_sre.SRE_Match object; span=(8, 14), match='deeply'>,
#  <_sre.SRE_Match object; span=(29, 33), match='only'>,
#  <_sre.SRE_Match object; span=(28, 35), match='heavily'>,
#  <_sre.SRE_Match object; span=(31, 44), match='uncomfortably'>,
#  <_sre.SRE_Match object; span=(2, 9), match='Hastily'>,
#  <_sre.SRE_Match object; span=(34, 40), match='nearly'>,
#  <_sre.SRE_Match object; span=(11, 16), match='dimly'>,
#  <_sre.SRE_Match object; span=(57, 65), match='fitfully'>,
#  <_sre.SRE_Match object; span=(2, 6), match='Only'>,
#  <_sre.SRE_Match object; span=(49, 59), match='absolutely'>,
#  <_sre.SRE_Match object; span=(33, 42), match='fervently'>,
#  <_sre.SRE_Match object; span=(31, 37), match='warmly'>,
#  <_sre.SRE_Match object; span=(36, 43), match='morally'>,
#  <_sre.SRE_Match object; span=(52, 59), match='grossly'>,
#  <_sre.SRE_Match object; span=(27, 33), match='likely'>,
#  <_sre.SRE_Match object; span=(5, 12), match='clearly'>,
#  <_sre.SRE_Match object; span=(33, 48), match='disinterestedly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='previously'>,
#  <_sre.SRE_Match object; span=(32, 41), match='pointedly'>,
#  <_sre.SRE_Match object; span=(27, 33), match='softly'>,
#  <_sre.SRE_Match object; span=(5, 11), match='slowly'>,
#  <_sre.SRE_Match object; span=(37, 43), match='nearly'>,
#  <_sre.SRE_Match object; span=(59, 67), match='silently'>,
#  <_sre.SRE_Match object; span=(32, 38), match='warmly'>,
#  <_sre.SRE_Match object; span=(41, 51), match='carelessly'>,
#  <_sre.SRE_Match object; span=(60, 66), match='really'>,
#  <_sre.SRE_Match object; span=(42, 48), match='really'>,
#  <_sre.SRE_Match object; span=(32, 42), match='thoroughly'>,
#  <_sre.SRE_Match object; span=(5, 11), match='hardly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='faintly'>,
#  <_sre.SRE_Match object; span=(20, 25), match='fully'>,
#  <_sre.SRE_Match object; span=(8, 19), match='frightfully'>,
#  <_sre.SRE_Match object; span=(13, 21), match='bitterly'>,
#  <_sre.SRE_Match object; span=(29, 36), match='finally'>,
#  <_sre.SRE_Match object; span=(36, 45), match='presently'>,
#  <_sre.SRE_Match object; span=(11, 19), match='mightily'>,
#  <_sre.SRE_Match object; span=(27, 33), match='timely'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(18, 30), match='particularly'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(57, 65), match='minutely'>,
#  <_sre.SRE_Match object; span=(10, 22), match='particularly'>,
#  <_sre.SRE_Match object; span=(16, 28), match='particularly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='certainly'>,
#  <_sre.SRE_Match object; span=(18, 28), match='cautiously'>,
#  <_sre.SRE_Match object; span=(24, 33), match='specially'>,
#  <_sre.SRE_Match object; span=(3, 8), match='daily'>,
#  <_sre.SRE_Match object; span=(6, 10), match='ally'>,
#  <_sre.SRE_Match object; span=(0, 10), match='stealthily'>,
#  <_sre.SRE_Match object; span=(0, 9), match='amazingly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='dexterously'>,
#  <_sre.SRE_Match object; span=(2, 10), match='Sullenly'>,
#  <_sre.SRE_Match object; span=(58, 67), match='partially'>,
#  <_sre.SRE_Match object; span=(9, 14), match='gaily'>,
#  <_sre.SRE_Match object; span=(3, 7), match='Only'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(42, 47), match='fully'>,
#  <_sre.SRE_Match object; span=(60, 65), match='bully'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Partly'>,
#  <_sre.SRE_Match object; span=(2, 12), match='Apparently'>,
#  <_sre.SRE_Match object; span=(10, 16), match='slowly'>,
#  <_sre.SRE_Match object; span=(39, 45), match='coldly'>,
#  <_sre.SRE_Match object; span=(2, 7), match='Sadly'>,
#  <_sre.SRE_Match object; span=(62, 67), match='early'>,
#  <_sre.SRE_Match object; span=(43, 50), match='Firstly'>,
#  <_sre.SRE_Match object; span=(7, 15), match='secondly'>,
#  <_sre.SRE_Match object; span=(23, 29), match='family'>,
#  <_sre.SRE_Match object; span=(12, 21), match='generally'>,
#  <_sre.SRE_Match object; span=(61, 67), match='likely'>,
#  <_sre.SRE_Match object; span=(42, 53), match='brilliantly'>,
#  <_sre.SRE_Match object; span=(2, 8), match='lonely'>,
#  <_sre.SRE_Match object; span=(0, 12), match='Occasionally'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(2, 10), match='Possibly'>,
#  <_sre.SRE_Match object; span=(32, 40), match='innately'>,
#  <_sre.SRE_Match object; span=(52, 58), match='freely'>,
#  <_sre.SRE_Match object; span=(21, 30), match='smilingly'>,
#  <_sre.SRE_Match object; span=(36, 46), match='changingly'>,
#  <_sre.SRE_Match object; span=(44, 51), match='sharply'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(30, 39), match='certainly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='really'>,
#  <_sre.SRE_Match object; span=(36, 42), match='really'>,
#  <_sre.SRE_Match object; span=(33, 37), match='only'>,
#  <_sre.SRE_Match object; span=(30, 42), match='immeasurably'>,
#  <_sre.SRE_Match object; span=(18, 26), match='friendly'>,
#  <_sre.SRE_Match object; span=(29, 35), match='kindly'>,
#  <_sre.SRE_Match object; span=(8, 14), match='Surely'>,
#  <_sre.SRE_Match object; span=(21, 35), match='unquestionably'>,
#  <_sre.SRE_Match object; span=(14, 23), match='devotedly'>,
#  <_sre.SRE_Match object; span=(15, 24), match='instantly'>,
#  <_sre.SRE_Match object; span=(38, 50), match='monotonously'>,
#  <_sre.SRE_Match object; span=(21, 33), match='resoundingly'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(46, 54), match='possibly'>,
#  <_sre.SRE_Match object; span=(15, 19), match='only'>,
#  <_sre.SRE_Match object; span=(25, 37), match='marvellously'>,
#  <_sre.SRE_Match object; span=(48, 58), match='thoroughly'>,
#  <_sre.SRE_Match object; span=(39, 50), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(30, 36), match='kindly'>,
#  <_sre.SRE_Match object; span=(6, 14), match='suddenly'>,
#  <_sre.SRE_Match object; span=(40, 52), match='unfrequently'>,
#  <_sre.SRE_Match object; span=(51, 60), match='specially'>,
#  <_sre.SRE_Match object; span=(36, 40), match='only'>,
#  <_sre.SRE_Match object; span=(26, 33), match='angrily'>,
#  <_sre.SRE_Match object; span=(41, 50), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='carefully'>,
#  <_sre.SRE_Match object; span=(48, 57), match='carefully'>,
#  <_sre.SRE_Match object; span=(9, 17), match='suddenly'>,
#  <_sre.SRE_Match object; span=(30, 39), match='instantly'>,
#  <_sre.SRE_Match object; span=(26, 33), match='quickly'>,
#  <_sre.SRE_Match object; span=(12, 16), match='only'>,
#  <_sre.SRE_Match object; span=(26, 32), match='slowly'>,
#  <_sre.SRE_Match object; span=(12, 18), match='surely'>,
#  <_sre.SRE_Match object; span=(49, 55), match='mostly'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(23, 30), match='usually'>,
#  <_sre.SRE_Match object; span=(4, 15), match='fortnightly'>,
#  <_sre.SRE_Match object; span=(22, 29), match='rapidly'>,
#  <_sre.SRE_Match object; span=(19, 26), match='ignobly'>,
#  <_sre.SRE_Match object; span=(32, 42), match='charmingly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='similarly'>,
#  <_sre.SRE_Match object; span=(22, 27), match='truly'>,
#  <_sre.SRE_Match object; span=(43, 48), match='truly'>,
#  <_sre.SRE_Match object; span=(61, 66), match='truly'>,
#  <_sre.SRE_Match object; span=(30, 34), match='only'>,
#  <_sre.SRE_Match object; span=(23, 29), match='slowly'>,
#  <_sre.SRE_Match object; span=(25, 37), match='consequently'>,
#  <_sre.SRE_Match object; span=(41, 47), match='family'>,
#  <_sre.SRE_Match object; span=(31, 42), match='exceedingly'>,
#  <_sre.SRE_Match object; span=(53, 60), match='worldly'>,
#  <_sre.SRE_Match object; span=(51, 58), match='totally'>,
#  <_sre.SRE_Match object; span=(33, 41), match='horribly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='nearly'>,
#  <_sre.SRE_Match object; span=(4, 15), match='immediately'>,
#  <_sre.SRE_Match object; span=(44, 51), match='earthly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='courtly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='goodly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='highly'>,
#  <_sre.SRE_Match object; span=(47, 50), match='fly'>,
#  <_sre.SRE_Match object; span=(44, 55), match='accordingly'>,
#  <_sre.SRE_Match object; span=(17, 26), match='perfectly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='eternally'>,
#  <_sre.SRE_Match object; span=(32, 44), match='artificially'>,
#  <_sre.SRE_Match object; span=(22, 28), match='surely'>,
#  <_sre.SRE_Match object; span=(30, 39), match='languidly'>,
#  <_sre.SRE_Match object; span=(34, 42), match='possibly'>,
#  <_sre.SRE_Match object; span=(59, 66), match='affably'>,
#  <_sre.SRE_Match object; span=(45, 51), match='slowly'>,
#  <_sre.SRE_Match object; span=(28, 35), match='quietly'>,
#  <_sre.SRE_Match object; span=(31, 41), match='handsomely'>,
#  <_sre.SRE_Match object; span=(30, 37), match='clearly'>,
#  <_sre.SRE_Match object; span=(14, 25), match='beautifully'>,
#  <_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(58, 70), match='occasionally'>,
#  <_sre.SRE_Match object; span=(39, 45), match='barely'>,
#  <_sre.SRE_Match object; span=(49, 57), match='probably'>,
#  <_sre.SRE_Match object; span=(40, 46), match='calmly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='unearthly'>,
#  <_sre.SRE_Match object; span=(59, 65), match='gently'>,
#  <_sre.SRE_Match object; span=(8, 15), match='happily'>,
#  <_sre.SRE_Match object; span=(36, 48), match='accidentally'>,
#  <_sre.SRE_Match object; span=(9, 17), match='suddenly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='smoothly'>,
#  <_sre.SRE_Match object; span=(9, 18), match='willingly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(0, 8), match='steadily'>,
#  <_sre.SRE_Match object; span=(0, 11), match='unwillingly'>,
#  <_sre.SRE_Match object; span=(23, 34), match='brilliantly'>,
#  <_sre.SRE_Match object; span=(1, 9), match='directly'>,
#  <_sre.SRE_Match object; span=(9, 16), match='quickly'>,
#  <_sre.SRE_Match object; span=(26, 30), match='only'>,
#  <_sre.SRE_Match object; span=(8, 14), match='merely'>,
#  <_sre.SRE_Match object; span=(28, 35), match='fixedly'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='promptly'>,
#  <_sre.SRE_Match object; span=(41, 49), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='Gradually'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quietly'>,
#  <_sre.SRE_Match object; span=(18, 28), match='dreadfully'>,
#  <_sre.SRE_Match object; span=(53, 60), match='quickly'>,
#  <_sre.SRE_Match object; span=(15, 23), match='tenderly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quickly'>,
#  <_sre.SRE_Match object; span=(63, 70), match='rapidly'>,
#  <_sre.SRE_Match object; span=(25, 36), match='impartially'>,
#  <_sre.SRE_Match object; span=(34, 46), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(21, 27), match='calmly'>,
#  <_sre.SRE_Match object; span=(40, 47), match='briskly'>,
#  <_sre.SRE_Match object; span=(20, 25), match='early'>,
#  <_sre.SRE_Match object; span=(9, 16), match='rapidly'>,
#  <_sre.SRE_Match object; span=(32, 39), match='courtly'>,
#  <_sre.SRE_Match object; span=(49, 56), match='clearly'>,
#  <_sre.SRE_Match object; span=(5, 14), match='expressly'>,
#  <_sre.SRE_Match object; span=(32, 42), match='pleasantly'>,
#  <_sre.SRE_Match object; span=(38, 45), match='sweetly'>,
#  <_sre.SRE_Match object; span=(43, 55), match='indefinitely'>,
#  <_sre.SRE_Match object; span=(14, 20), match='family'>,
#  <_sre.SRE_Match object; span=(20, 27), match='happily'>,
#  <_sre.SRE_Match object; span=(19, 26), match='happily'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(9, 22), match='comparatively'>,
#  <_sre.SRE_Match object; span=(3, 12), match='elegantly'>,
#  <_sre.SRE_Match object; span=(36, 44), match='gloomily'>,
#  <_sre.SRE_Match object; span=(60, 66), match='family'>,
#  <_sre.SRE_Match object; span=(35, 41), match='family'>,
#  <_sre.SRE_Match object; span=(4, 11), match='lightly'>,
#  <_sre.SRE_Match object; span=(5, 17), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(21, 25), match='only'>,
#  <_sre.SRE_Match object; span=(9, 16), match='ghastly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='family'>,
#  <_sre.SRE_Match object; span=(4, 14), match='delicately'>,
#  <_sre.SRE_Match object; span=(7, 13), match='family'>,
#  <_sre.SRE_Match object; span=(29, 36), match='equally'>,
#  <_sre.SRE_Match object; span=(0, 7), match='cruelly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='quietly'>,
#  <_sre.SRE_Match object; span=(62, 67), match='sadly'>,
#  <_sre.SRE_Match object; span=(16, 24), match='scarcely'>,
#  <_sre.SRE_Match object; span=(21, 27), match='slowly'>,
#  <_sre.SRE_Match object; span=(16, 26), match='graciously'>,
#  <_sre.SRE_Match object; span=(12, 18), match='family'>,
#  <_sre.SRE_Match object; span=(0, 6), match='family'>,
#  <_sre.SRE_Match object; span=(22, 30), match='brightly'>,
#  <_sre.SRE_Match object; span=(49, 62), match='indifferently'>,
#  <_sre.SRE_Match object; span=(34, 41), match='courtly'>,
#  <_sre.SRE_Match object; span=(58, 66), match='forcibly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='handsomely'>,
#  <_sre.SRE_Match object; span=(43, 49), match='gently'>,
#  <_sre.SRE_Match object; span=(46, 52), match='softly'>,
#  <_sre.SRE_Match object; span=(35, 47), match='impenitently'>,
#  <_sre.SRE_Match object; span=(14, 18), match='only'>,
#  <_sre.SRE_Match object; span=(44, 51), match='blindly'>,
#  <_sre.SRE_Match object; span=(54, 68), match='conventionally'>,
#  <_sre.SRE_Match object; span=(15, 21), match='hardly'>,
#  <_sre.SRE_Match object; span=(14, 21), match='blindly'>,
#  <_sre.SRE_Match object; span=(47, 54), match='usually'>,
#  <_sre.SRE_Match object; span=(18, 25), match='soundly'>,
#  <_sre.SRE_Match object; span=(59, 66), match='ghostly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='rarely'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(19, 25), match='Surely'>,
#  <_sre.SRE_Match object; span=(57, 64), match='hastily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='stupidly'>,
#  <_sre.SRE_Match object; span=(38, 44), match='highly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='suddenly'>,
#  <_sre.SRE_Match object; span=(44, 50), match='easily'>,
#  <_sre.SRE_Match object; span=(14, 23), match='unusually'>,
#  <_sre.SRE_Match object; span=(16, 22), match='mostly'>,
#  <_sre.SRE_Match object; span=(8, 18), match='invariably'>,
#  <_sre.SRE_Match object; span=(35, 43), match='tenderly'>,
#  <_sre.SRE_Match object; span=(19, 25), match='lately'>,
#  <_sre.SRE_Match object; span=(37, 46), match='gradually'>,
#  <_sre.SRE_Match object; span=(11, 21), match='frequently'>,
#  <_sre.SRE_Match object; span=(19, 26), match='equably'>,
#  <_sre.SRE_Match object; span=(19, 25), match='coldly'>,
#  <_sre.SRE_Match object; span=(25, 38), match='deferentially'>,
#  <_sre.SRE_Match object; span=(0, 9), match='earnestly'>,
#  <_sre.SRE_Match object; span=(54, 60), match='fondly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='dearly'>,
#  <_sre.SRE_Match object; span=(60, 69), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(25, 37), match='respectfully'>,
#  <_sre.SRE_Match object; span=(7, 12), match='early'>,
#  <_sre.SRE_Match object; span=(16, 22), match='hardly'>,
#  <_sre.SRE_Match object; span=(39, 49), match='mournfully'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(22, 28), match='coldly'>,
#  <_sre.SRE_Match object; span=(44, 53), match='evidently'>,
#  <_sre.SRE_Match object; span=(16, 25), match='feelingly'>,
#  <_sre.SRE_Match object; span=(60, 66), match='nearly'>,
#  <_sre.SRE_Match object; span=(16, 23), match='equally'>,
#  <_sre.SRE_Match object; span=(38, 46), match='modestly'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(57, 63), match='likely'>,
#  <_sre.SRE_Match object; span=(43, 54), match='immediately'>,
#  <_sre.SRE_Match object; span=(27, 33), match='purely'>,
#  <_sre.SRE_Match object; span=(35, 45), match='gratefully'>,
#  <_sre.SRE_Match object; span=(44, 50), match='really'>,
#  <_sre.SRE_Match object; span=(40, 46), match='slowly'>,
#  <_sre.SRE_Match object; span=(40, 48), match='slightly'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Willingly'>,
#  <_sre.SRE_Match object; span=(39, 47), match='directly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='lightly'>,
#  <_sre.SRE_Match object; span=(14, 20), match='softly'>,
#  <_sre.SRE_Match object; span=(18, 27), match='presently'>,
#  <_sre.SRE_Match object; span=(16, 23), match='heavily'>,
#  <_sre.SRE_Match object; span=(31, 41), match='handsomely'>,
#  <_sre.SRE_Match object; span=(21, 36), match='correspondingly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='portly'>,
#  <_sre.SRE_Match object; span=(14, 21), match='usually'>,
#  <_sre.SRE_Match object; span=(51, 57), match='slowly'>,
#  <_sre.SRE_Match object; span=(37, 47), match='boastfully'>,
#  <_sre.SRE_Match object; span=(0, 5), match='bully'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Certainly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='rapidly'>,
#  <_sre.SRE_Match object; span=(53, 59), match='easily'>,
#  <_sre.SRE_Match object; span=(47, 53), match='really'>,
#  <_sre.SRE_Match object; span=(44, 50), match='really'>,
#  <_sre.SRE_Match object; span=(0, 7), match='clearly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='worldly'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(15, 28), match='unaccountably'>,
#  <_sre.SRE_Match object; span=(0, 13), match='magnificently'>,
#  <_sre.SRE_Match object; span=(51, 65), match='confidentially'>,
#  <_sre.SRE_Match object; span=(12, 21), match='dubiously'>,
#  <_sre.SRE_Match object; span=(62, 70), match='friendly'>,
#  <_sre.SRE_Match object; span=(55, 61), match='really'>,
#  <_sre.SRE_Match object; span=(0, 10), match='internally'>,
#  <_sre.SRE_Match object; span=(0, 11), match='perceptibly'>,
#  <_sre.SRE_Match object; span=(56, 68), match='forensically'>,
#  <_sre.SRE_Match object; span=(10, 20), match='infinitely'>,
#  <_sre.SRE_Match object; span=(52, 58), match='mildly'>,
#  <_sre.SRE_Match object; span=(7, 14), match='exactly'>,
#  <_sre.SRE_Match object; span=(44, 59), match='disrespectfully'>,
#  <_sre.SRE_Match object; span=(63, 70), match='usually'>,
#  <_sre.SRE_Match object; span=(53, 61), match='probably'>,
#  <_sre.SRE_Match object; span=(47, 59), match='deliberately'>,
#  <_sre.SRE_Match object; span=(55, 64), match='correctly'>,
#  <_sre.SRE_Match object; span=(31, 35), match='only'>,
#  <_sre.SRE_Match object; span=(41, 48), match='quickly'>,
#  <_sre.SRE_Match object; span=(28, 34), match='family'>,
#  <_sre.SRE_Match object; span=(0, 9), match='expressly'>,
#  <_sre.SRE_Match object; span=(13, 17), match='only'>,
#  <_sre.SRE_Match object; span=(0, 9), match='popularly'>,
#  <_sre.SRE_Match object; span=(2, 13), match='Accordingly'>,
#  <_sre.SRE_Match object; span=(35, 41), match='coldly'>,
#  <_sre.SRE_Match object; span=(9, 15), match='family'>,
#  <_sre.SRE_Match object; span=(60, 67), match='worldly'>,
#  <_sre.SRE_Match object; span=(60, 67), match='worldly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='hardly'>,
#  <_sre.SRE_Match object; span=(18, 24), match='really'>,
#  <_sre.SRE_Match object; span=(53, 61), match='stupidly'>,
#  <_sre.SRE_Match object; span=(43, 52), match='certainly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='rarely'>,
#  <_sre.SRE_Match object; span=(11, 18), match='vaguely'>,
#  <_sre.SRE_Match object; span=(32, 40), match='scantily'>,
#  <_sre.SRE_Match object; span=(10, 16), match='gently'>,
#  <_sre.SRE_Match object; span=(55, 63), match='steadily'>,
#  <_sre.SRE_Match object; span=(46, 54), match='modestly'>,
#  <_sre.SRE_Match object; span=(12, 16), match='idly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='fervently'>,
#  <_sre.SRE_Match object; span=(14, 20), match='gently'>,
#  <_sre.SRE_Match object; span=(49, 59), match='mournfully'>,
#  <_sre.SRE_Match object; span=(0, 9), match='outwardly'>,
#  <_sre.SRE_Match object; span=(5, 13), match='tenderly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='grisly'>,
#  <_sre.SRE_Match object; span=(25, 31), match='mostly'>,
#  <_sre.SRE_Match object; span=(25, 29), match='only'>,
#  <_sre.SRE_Match object; span=(28, 39), match='incessantly'>,
#  <_sre.SRE_Match object; span=(28, 37), match='Naturally'>,
#  <_sre.SRE_Match object; span=(37, 44), match='greatly'>,
#  <_sre.SRE_Match object; span=(37, 40), match='Cly'>,
#  <_sre.SRE_Match object; span=(48, 54), match='loudly'>,
#  <_sre.SRE_Match object; span=(12, 19), match='closely'>,
#  <_sre.SRE_Match object; span=(37, 46), match='hurriedly'>,
#  <_sre.SRE_Match object; span=(45, 56), match='immediately'>,
#  <_sre.SRE_Match object; span=(0, 8), match='modestly'>,
#  <_sre.SRE_Match object; span=(48, 58), match='alarmingly'>,
#  <_sre.SRE_Match object; span=(25, 35), match='disorderly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='finally'>,
#  <_sre.SRE_Match object; span=(6, 9), match='Cly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='roughly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='gradually'>,
#  <_sre.SRE_Match object; span=(20, 28), match='maturely'>,
#  <_sre.SRE_Match object; span=(20, 23), match='Cly'>,
#  <_sre.SRE_Match object; span=(58, 68), match='previously'>,
#  <_sre.SRE_Match object; span=(52, 64), match='unfrequently'>,
#  <_sre.SRE_Match object; span=(46, 53), match='briskly'>,
#  <_sre.SRE_Match object; span=(44, 52), match='sullenly'>,
#  <_sre.SRE_Match object; span=(60, 64), match='ugly'>,
#  <_sre.SRE_Match object; span=(13, 16), match='fly'>,
#  <_sre.SRE_Match object; span=(21, 32), match='affectingly'>,
#  <_sre.SRE_Match object; span=(47, 53), match='family'>,
#  <_sre.SRE_Match object; span=(6, 12), match='nearly'>,
#  <_sre.SRE_Match object; span=(23, 27), match='only'>,
#  <_sre.SRE_Match object; span=(0, 6), match='lonely'>,
#  <_sre.SRE_Match object; span=(0, 8), match='silently'>,
#  <_sre.SRE_Match object; span=(6, 12), match='nimbly'>,
#  <_sre.SRE_Match object; span=(64, 70), match='softly'>,
#  <_sre.SRE_Match object; span=(38, 47), match='Presently'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(19, 32), match='perseveringly'>,
#  <_sre.SRE_Match object; span=(62, 68), match='highly'>,
#  <_sre.SRE_Match object; span=(56, 65), match='cunningly'>,
#  <_sre.SRE_Match object; span=(46, 57), match='incessantly'>,
#  <_sre.SRE_Match object; span=(4, 10), match='family'>,
#  <_sre.SRE_Match object; span=(25, 34), match='similarly'>,
#  <_sre.SRE_Match object; span=(49, 55), match='lively'>,
#  <_sre.SRE_Match object; span=(21, 26), match='early'>,
#  <_sre.SRE_Match object; span=(61, 70), match='unusually'>,
#  <_sre.SRE_Match object; span=(5, 10), match='early'>,
#  <_sre.SRE_Match object; span=(63, 68), match='early'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(0, 8), match='musingly'>,
#  <_sre.SRE_Match object; span=(26, 34), match='formerly'>,
#  <_sre.SRE_Match object; span=(30, 36), match='singly'>,
#  <_sre.SRE_Match object; span=(26, 35), match='carefully'>,
#  <_sre.SRE_Match object; span=(54, 59), match='reply'>,
#  <_sre.SRE_Match object; span=(60, 66), match='slowly'>,
#  <_sre.SRE_Match object; span=(50, 56), match='softly'>,
#  <_sre.SRE_Match object; span=(11, 20), match='unluckily'>,
#  <_sre.SRE_Match object; span=(7, 14), match='vividly'>,
#  <_sre.SRE_Match object; span=(24, 36), match='consequently'>,
#  <_sre.SRE_Match object; span=(32, 38), match='darkly'>,
#  <_sre.SRE_Match object; span=(15, 22), match='equally'>,
#  <_sre.SRE_Match object; span=(37, 45), match='Formerly'>,
#  <_sre.SRE_Match object; span=(50, 57), match='sternly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='strikingly'>,
#  <_sre.SRE_Match object; span=(44, 53), match='certainly'>,
#  <_sre.SRE_Match object; span=(29, 36), match='finally'>,
#  <_sre.SRE_Match object; span=(60, 68), match='actually'>,
#  <_sre.SRE_Match object; span=(20, 30), match='faithfully'>,
#  <_sre.SRE_Match object; span=(8, 17), match='willingly'>,
#  <_sre.SRE_Match object; span=(6, 12), match='easily'>,
#  <_sre.SRE_Match object; span=(28, 39), match='judiciously'>,
#  <_sre.SRE_Match object; span=(22, 33), match='Judiciously'>,
#  <_sre.SRE_Match object; span=(49, 55), match='easily'>,
#  <_sre.SRE_Match object; span=(43, 53), match='constantly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='expressly'>,
#  <_sre.SRE_Match object; span=(49, 57), match='brightly'>,
#  <_sre.SRE_Match object; span=(27, 37), match='infallibly'>,
#  <_sre.SRE_Match object; span=(43, 55), match='additionally'>,
#  <_sre.SRE_Match object; span=(19, 31), match='additionally'>,
#  <_sre.SRE_Match object; span=(43, 53), match='composedly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='mightily'>,
#  <_sre.SRE_Match object; span=(46, 55), match='elegantly'>,
#  <_sre.SRE_Match object; span=(12, 22), match='handsomely'>,
#  <_sre.SRE_Match object; span=(34, 44), match='absolutely'>,
#  <_sre.SRE_Match object; span=(5, 8), match='fly'>,
#  <_sre.SRE_Match object; span=(36, 48), match='reflectively'>,
#  <_sre.SRE_Match object; span=(41, 45), match='only'>,
#  <_sre.SRE_Match object; span=(24, 38), match='superciliously'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(3, 8), match='Truly'>,
#  <_sre.SRE_Match object; span=(58, 61), match='fly'>,
#  <_sre.SRE_Match object; span=(51, 59), match='amicably'>,
#  <_sre.SRE_Match object; span=(16, 22), match='slowly'>,
#  <_sre.SRE_Match object; span=(10, 15), match='analy'>,
#  <_sre.SRE_Match object; span=(14, 23), match='naturally'>,
#  <_sre.SRE_Match object; span=(23, 37), match='affectionately'>,
#  <_sre.SRE_Match object; span=(24, 31), match='finally'>,
#  <_sre.SRE_Match object; span=(30, 40), match='accurately'>,
#  <_sre.SRE_Match object; span=(17, 26), match='generally'>,
#  <_sre.SRE_Match object; span=(36, 47), match='immediately'>,
#  <_sre.SRE_Match object; span=(9, 16), match='finally'>,
#  <_sre.SRE_Match object; span=(43, 55), match='complacently'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(42, 48), match='firmly'>,
#  <_sre.SRE_Match object; span=(31, 41), match='composedly'>,
#  <_sre.SRE_Match object; span=(26, 38), match='thoughtfully'>,
#  <_sre.SRE_Match object; span=(10, 19), match='certainly'>,
#  <_sre.SRE_Match object; span=(25, 36), match='assiduously'>,
#  <_sre.SRE_Match object; span=(36, 45), match='gradually'>,
#  <_sre.SRE_Match object; span=(18, 27), match='generally'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Decidedly'>,
#  <_sre.SRE_Match object; span=(18, 24), match='nimbly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='decidedly'>,
#  <_sre.SRE_Match object; span=(16, 26), match='separately'>,
#  <_sre.SRE_Match object; span=(53, 59), match='deftly'>,
#  <_sre.SRE_Match object; span=(14, 23), match='certainly'>,
#  <_sre.SRE_Match object; span=(40, 52), match='occasionally'>,
#  <_sre.SRE_Match object; span=(31, 37), match='coolly'>,
#  <_sre.SRE_Match object; span=(28, 36), match='vacantly'>,
#  <_sre.SRE_Match object; span=(38, 44), match='airily'>,
#  <_sre.SRE_Match object; span=(32, 37), match='drily'>,
#  <_sre.SRE_Match object; span=(53, 63), match='profoundly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='certainly'>,
#  <_sre.SRE_Match object; span=(22, 31), match='gradually'>,
#  <_sre.SRE_Match object; span=(3, 12), match='Perfectly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='family'>,
#  <_sre.SRE_Match object; span=(25, 33), match='steadily'>,
#  <_sre.SRE_Match object; span=(39, 46), match='exactly'>,
#  <_sre.SRE_Match object; span=(7, 15), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 9), match='presently'>,
#  <_sre.SRE_Match object; span=(5, 12), match='shortly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='frightfully'>,
#  <_sre.SRE_Match object; span=(35, 41), match='surely'>,
#  <_sre.SRE_Match object; span=(8, 18), match='pleasantly'>,
#  <_sre.SRE_Match object; span=(51, 57), match='deeply'>,
#  <_sre.SRE_Match object; span=(0, 8), match='scarcely'>,
#  <_sre.SRE_Match object; span=(13, 21), match='tenderly'>,
#  <_sre.SRE_Match object; span=(7, 12), match='fully'>,
#  <_sre.SRE_Match object; span=(0, 8), match='entirely'>,
#  <_sre.SRE_Match object; span=(32, 36), match='only'>,
#  <_sre.SRE_Match object; span=(46, 55), match='perfectly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='Hardly'>,
#  <_sre.SRE_Match object; span=(12, 21), match='fervently'>,
#  <_sre.SRE_Match object; span=(19, 27), match='solemnly'>,
#  <_sre.SRE_Match object; span=(51, 59), match='formerly'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(0, 14), match='affectionately'>,
#  <_sre.SRE_Match object; span=(6, 13), match='timidly'>,
#  <_sre.SRE_Match object; span=(56, 62), match='softly'>,
#  <_sre.SRE_Match object; span=(31, 39), match='brightly'>,
#  <_sre.SRE_Match object; span=(42, 54), match='sufficiently'>,
#  <_sre.SRE_Match object; span=(32, 39), match='lightly'>,
#  <_sre.SRE_Match object; span=(3, 9), match='Really'>,
#  <_sre.SRE_Match object; span=(8, 14), match='highly'>,
#  <_sre.SRE_Match object; span=(30, 39), match='beamingly'>,
#  <_sre.SRE_Match object; span=(52, 64), match='unhandsomely'>,
#  <_sre.SRE_Match object; span=(54, 64), match='soothingly'>,
#  <_sre.SRE_Match object; span=(32, 45), match='comparatively'>,
#  <_sre.SRE_Match object; span=(18, 24), match='deadly'>,
#  <_sre.SRE_Match object; span=(55, 61), match='lately'>,
#  <_sre.SRE_Match object; span=(0, 7), match='happily'>,
#  <_sre.SRE_Match object; span=(40, 45), match='newly'>,
#  <_sre.SRE_Match object; span=(31, 37), match='gently'>,
#  <_sre.SRE_Match object; span=(9, 18), match='naturally'>,
#  <_sre.SRE_Match object; span=(43, 51), match='drearily'>,
#  <_sre.SRE_Match object; span=(19, 28), match='presently'>,
#  <_sre.SRE_Match object; span=(46, 57), match='inquiringly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='impatiently'>,
#  <_sre.SRE_Match object; span=(24, 36), match='mechanically'>,
#  <_sre.SRE_Match object; span=(34, 38), match='only'>,
#  <_sre.SRE_Match object; span=(39, 48), match='furtively'>,
#  <_sre.SRE_Match object; span=(28, 42), match='professionally'>,
#  <_sre.SRE_Match object; span=(0, 11), match='attentively'>,
#  <_sre.SRE_Match object; span=(44, 50), match='merely'>,
#  <_sre.SRE_Match object; span=(47, 54), match='finally'>,
#  <_sre.SRE_Match object; span=(44, 54), match='cheerfully'>,
#  <_sre.SRE_Match object; span=(15, 20), match='reply'>,
#  <_sre.SRE_Match object; span=(44, 54), match='confusedly'>,
#  <_sre.SRE_Match object; span=(43, 50), match='quietly'>,
#  <_sre.SRE_Match object; span=(28, 37), match='precisely'>,
#  <_sre.SRE_Match object; span=(25, 33), match='friendly'>,
#  <_sre.SRE_Match object; span=(21, 27), match='slowly'>,
#  <_sre.SRE_Match object; span=(33, 43), match='dreadfully'>,
#  <_sre.SRE_Match object; span=(32, 42), match='distinctly'>,
#  <_sre.SRE_Match object; span=(10, 16), match='calmly'>,
#  <_sre.SRE_Match object; span=(0, 7), match='giddily'>,
#  <_sre.SRE_Match object; span=(0, 8), match='actually'>,
#  <_sre.SRE_Match object; span=(48, 53), match='early'>,
#  <_sre.SRE_Match object; span=(27, 37), match='cautiously'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(51, 60), match='purposely'>,
#  <_sre.SRE_Match object; span=(27, 36), match='evidently'>,
#  <_sre.SRE_Match object; span=(29, 39), match='composedly'>,
#  <_sre.SRE_Match object; span=(51, 60), match='feelingly'>,
#  <_sre.SRE_Match object; span=(49, 55), match='deeply'>,
#  <_sre.SRE_Match object; span=(41, 52), match='attentively'>,
#  <_sre.SRE_Match object; span=(49, 63), match='affectionately'>,
#  <_sre.SRE_Match object; span=(32, 44), match='particularly'>,
#  <_sre.SRE_Match object; span=(35, 43), match='publicly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='completely'>,
#  <_sre.SRE_Match object; span=(56, 66), match='constantly'>,
#  <_sre.SRE_Match object; span=(17, 30), match='unfortunately'>,
#  <_sre.SRE_Match object; span=(49, 59), match='distinctly'>,
#  <_sre.SRE_Match object; span=(0, 11), match='collectedly'>,
#  <_sre.SRE_Match object; span=(0, 10), match='originally'>,
#  <_sre.SRE_Match object; span=(22, 26), match='only'>,
#  <_sre.SRE_Match object; span=(16, 20), match='rely'>,
#  <_sre.SRE_Match object; span=(59, 66), match='clearly'>,
#  <_sre.SRE_Match object; span=(35, 43), match='sensibly'>,
#  <_sre.SRE_Match object; span=(25, 31), match='gently'>,
#  <_sre.SRE_Match object; span=(47, 54), match='vividly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='desolately'>,
#  <_sre.SRE_Match object; span=(50, 57), match='vaguely'>,
#  <_sre.SRE_Match object; span=(54, 63), match='unusually'>,
#  <_sre.SRE_Match object; span=(40, 46), match='easily'>,
#  <_sre.SRE_Match object; span=(32, 38), match='likely'>,
#  <_sre.SRE_Match object; span=(32, 38), match='slowly'>,
#  <_sre.SRE_Match object; span=(8, 14), match='really'>,
#  <_sre.SRE_Match object; span=(13, 20), match='happily'>,
#  <_sre.SRE_Match object; span=(12, 24), match='unexpectedly'>,
#  <_sre.SRE_Match object; span=(0, 9), match='nervously'>,
#  <_sre.SRE_Match object; span=(57, 66), match='nervously'>,
#  <_sre.SRE_Match object; span=(36, 48), match='consistently'>,
#  <_sre.SRE_Match object; span=(53, 64), match='frightfully'>,
#  <_sre.SRE_Match object; span=(13, 17), match='only'>,
#  <_sre.SRE_Match object; span=(35, 46), match='tremulously'>,
#  <_sre.SRE_Match object; span=(23, 27), match='only'>,
#  <_sre.SRE_Match object; span=(12, 19), match='readily'>,
#  <_sre.SRE_Match object; span=(40, 49), match='perfectly'>,
#  <_sre.SRE_Match object; span=(4, 14), match='previously'>,
#  <_sre.SRE_Match object; span=(44, 54), match='previously'>,
#  <_sre.SRE_Match object; span=(11, 16), match='newly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='scarcely'>,
#  <_sre.SRE_Match object; span=(4, 12), match='bitterly'>,
#  <_sre.SRE_Match object; span=(9, 17), match='strongly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='scarcely'>,
#  <_sre.SRE_Match object; span=(29, 35), match='busily'>,
#  <_sre.SRE_Match object; span=(13, 23), match='tranquilly'>,
#  <_sre.SRE_Match object; span=(47, 56), match='perfectly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='slowly'>,
#  <_sre.SRE_Match object; span=(31, 39), match='scarcely'>,
#  <_sre.SRE_Match object; span=(40, 45), match='early'>,
#  <_sre.SRE_Match object; span=(7, 13), match='busily'>,
#  <_sre.SRE_Match object; span=(38, 46), match='friendly'>,
#  <_sre.SRE_Match object; span=(28, 34), match='unruly'>,
#  <_sre.SRE_Match object; span=(26, 32), match='wholly'>,
#  <_sre.SRE_Match object; span=(21, 30), match='comically'>,
#  <_sre.SRE_Match object; span=(13, 19), match='rarely'>,
#  <_sre.SRE_Match object; span=(14, 20), match='really'>,
#  <_sre.SRE_Match object; span=(12, 19), match='usually'>,
#  <_sre.SRE_Match object; span=(0, 9), match='unhappily'>,
#  <_sre.SRE_Match object; span=(22, 34), match='particularly'>,
#  <_sre.SRE_Match object; span=(20, 30), match='delicately'>,
#  <_sre.SRE_Match object; span=(0, 12), match='occasionally'>,
#  <_sre.SRE_Match object; span=(30, 36), match='surely'>,
#  <_sre.SRE_Match object; span=(18, 28), match='originally'>,
#  <_sre.SRE_Match object; span=(37, 45), match='suitably'>,
#  <_sre.SRE_Match object; span=(11, 15), match='only'>,
#  <_sre.SRE_Match object; span=(0, 10), match='menacingly'>,
#  <_sre.SRE_Match object; span=(20, 24), match='July'>,
#  <_sre.SRE_Match object; span=(5, 13), match='actually'>,
#  <_sre.SRE_Match object; span=(3, 13), match='positively'>,
#  <_sre.SRE_Match object; span=(34, 40), match='really'>,
#  <_sre.SRE_Match object; span=(16, 23), match='soundly'>,
#  <_sre.SRE_Match object; span=(61, 65), match='Only'>,
#  <_sre.SRE_Match object; span=(30, 36), match='easily'>,
#  <_sre.SRE_Match object; span=(34, 46), match='convulsively'>,
#  <_sre.SRE_Match object; span=(25, 34), match='crookedly'>,
#  <_sre.SRE_Match object; span=(20, 29), match='variously'>,
#  <_sre.SRE_Match object; span=(15, 21), match='doubly'>,
#  <_sre.SRE_Match object; span=(60, 65), match='dimly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='nearly'>,
#  <_sre.SRE_Match object; span=(10, 20), match='faithfully'>,
#  <_sre.SRE_Match object; span=(52, 61), match='evidently'>,
#  <_sre.SRE_Match object; span=(44, 56), match='occasionally'>,
#  <_sre.SRE_Match object; span=(7, 17), match='especially'>,
#  <_sre.SRE_Match object; span=(0, 4), match='only'>,
#  <_sre.SRE_Match object; span=(15, 21), match='slowly'>,
#  <_sre.SRE_Match object; span=(21, 28), match='heavily'>,
#  <_sre.SRE_Match object; span=(56, 60), match='only'>,
#  <_sre.SRE_Match object; span=(56, 63), match='heavily'>,
#  <_sre.SRE_Match object; span=(19, 25), match='slowly'>,
#  <_sre.SRE_Match object; span=(49, 56), match='closely'>,
#  <_sre.SRE_Match object; span=(45, 53), match='greedily'>,
#  <_sre.SRE_Match object; span=(35, 41), match='deeply'>,
#  <_sre.SRE_Match object; span=(36, 46), match='wrathfully'>,
#  <_sre.SRE_Match object; span=(16, 24), match='suddenly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='suddenly'>,
#  <_sre.SRE_Match object; span=(54, 65), match='turbulently'>,
#  <_sre.SRE_Match object; span=(11, 18), match='fixedly'>,
#  <_sre.SRE_Match object; span=(11, 19), match='suddenly'>,
#  <_sre.SRE_Match object; span=(40, 46), match='loudly'>,
#  <_sre.SRE_Match object; span=(54, 58), match='July'>,
#  <_sre.SRE_Match object; span=(0, 6), match='easily'>,
#  <_sre.SRE_Match object; span=(32, 36), match='only'>,
#  <_sre.SRE_Match object; span=(57, 66), match='extremely'>,
#  <_sre.SRE_Match object; span=(25, 37), match='portentously'>,
#  <_sre.SRE_Match object; span=(15, 23), match='mightily'>,
#  <_sre.SRE_Match object; span=(48, 56), match='suddenly'>,
#  <_sre.SRE_Match object; span=(29, 43), match='contemptuously'>,
#  <_sre.SRE_Match object; span=(0, 11), match='steadfastly'>,
#  <_sre.SRE_Match object; span=(2, 11), match='Instantly'>,
#  <_sre.SRE_Match object; span=(47, 51), match='only'>,
#  <_sre.SRE_Match object; span=(14, 18), match='ugly'>,
#  <_sre.SRE_Match object; span=(13, 24), match='immediately'>,
#  <_sre.SRE_Match object; span=(28, 37), match='Similarly'>,
#  <_sre.SRE_Match object; span=(35, 42), match='readily'>,
#  <_sre.SRE_Match object; span=(50, 56), match='kindly'>,
#  <_sre.SRE_Match object; span=(20, 28), match='directly'>,
#  <_sre.SRE_Match object; span=(21, 33), match='surprisingly'>,
#  <_sre.SRE_Match object; span=(15, 23), match='directly'>,
#  <_sre.SRE_Match object; span=(22, 28), match='deadly'>,
#  <_sre.SRE_Match object; span=(0, 8), match='silently'>,
#  <_sre.SRE_Match object; span=(27, 39), match='passionately'>,
#  <_sre.SRE_Match object; span=(18, 25), match='sternly'>,
#  <_sre.SRE_Match object; span=(34, 43), match='patiently'>,
#  <_sre.SRE_Match object; span=(36, 45), match='Gradually'>,
#  <_sre.SRE_Match object; span=(32, 38), match='gently'>,
#  <_sre.SRE_Match object; span=(4, 8), match='only'>,
#  <_sre.SRE_Match object; span=(31, 36), match='daily'>,
#  <_sre.SRE_Match object; span=(14, 22), match='probably'>,
#  <_sre.SRE_Match object; span=(0, 9), match='expressly'>,
#  <_sre.SRE_Match object; span=(0, 6), match='surely'>,
#  <_sre.SRE_Match object; span=(61, 67), match='lonely'>,
#  ...]

# %% [markdown]
# ### 5.
# How many times does Charles Dickens use the pattern **WORD, WORD, and WORD** in this novel (for example `red, bluff, and free`)?

# %%
pattern = r'[a-zA-Z]+, [a-zA-Z]+, and [a-zA-Z]+'

results = re.findall(pattern, text)
len(results)
# Out:
# 78
